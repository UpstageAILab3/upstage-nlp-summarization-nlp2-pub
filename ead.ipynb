# %%
import pandas as pd

translated = pd.read_csv('./dj/translated.csv')

# %%
translated.columns
# Out:
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'fname', 'dialogue',
#        'summary', 'topic', 'combined_text', 'similarity', 'topic_nouns',
#        'topic_percent', 'topic_similarity', 'combined_similarity', 'k_percent',
#        'k_percent_dialogue', 'topic_dialogue_similarity', 'english_words',
#        'english_words_count'],
#       dtype='object')

# %%
fnames = ['train_6812', 'train_10900', 'train_10896', 'train_10897']

# %%
translated
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 translated
#
# NameError: name 'translated' is not defined

# %%
translated.sort_values(by='k_percent')
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0        fname  \
# 6812           6812          6812        6812   train_6812
# 10900         10900         10900       10900  train_10900
# 10896         10896         10896       10896  train_10896
# 10897         10897         10897       10897  train_10897
# 5155           5155          5155        5155   train_5155
# ...             ...           ...         ...          ...
# 7182           7182          7182        7182   train_7182
# 7194           7194          7194        7194   train_7194
# 7207           7207          7207        7207   train_7207
# 7217           7217          7217        7217   train_7217
# 0                 0             0           0      train_0
#
#                                                 dialogue  \
# 6812   #person1#: 안녕하세요, 할머니. 정말 다시 만나는 것을 좋아합니다.\n#P...
# 10900  #person1#: 좋아, 테일러, 시작하자. 첫 번째 직업에 대해 말해줘.\r\n...
# 10896  #person1#: 기분이 어떻습니까?\r\n#person2#: 나쁜 코는 계속 흐...
# ...

# %%
translated.sort_values(by='combined_similarity').head(200)
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0        fname  \
# 7557           7557          7557        7557   train_7557
# 10136         10136         10136       10136  train_10136
# 7551           7551          7551        7551   train_7551
# 9194           9194          9194        9194   train_9194
# 11655         11655         11655       11655  train_11658
# ...             ...           ...         ...          ...
# 8946           8946          8946        8946   train_8946
# 4345           4345          4345        4345   train_4345
# 7247           7247          7247        7247   train_7247
# 10688         10688         10688       10688  train_10688
# 10854         10854         10854       10854  train_10854
#
#                                                 dialogue  \
# 7557   #Person1#: 딩 씨, 안녕하세요? 저는 존 브라운입니다.\n#Person2#...
# 10136  #person1#: 안녕하세요. 도와 줄 것이 있습니까?\n#person2#: 글쎄...
# 7551   #person1#: 좋아요, 최신지도가 있습니다. 공항으로가는 길을 점검하십시오.\...
# ...

# %%
low_end
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0        fname  \
# 7557           7557          7557        7557   train_7557
# 10136         10136         10136       10136  train_10136
# 7551           7551          7551        7551   train_7551
# 9194           9194          9194        9194   train_9194
# 11655         11655         11655       11655  train_11658
# ...             ...           ...         ...          ...
# 8946           8946          8946        8946   train_8946
# 4345           4345          4345        4345   train_4345
# 7247           7247          7247        7247   train_7247
# 10688         10688         10688       10688  train_10688
# 10854         10854         10854       10854  train_10854
#
#                                                 dialogue  \
# 7557   #Person1#: 딩 씨, 안녕하세요? 저는 존 브라운입니다.\n#Person2#...
# 10136  #person1#: 안녕하세요. 도와 줄 것이 있습니까?\n#person2#: 글쎄...
# 7551   #person1#: 좋아요, 최신지도가 있습니다. 공항으로가는 길을 점검하십시오.\...
# ...

# %%
a = low_end['fname']

# %%
train = pd.read_csv('./dj/data/train.csv')

# %%
train
# Out:
#              fname                                           dialogue  \
# 0          train_0  #Person1#: 안녕하세요, 스미스씨. 저는 호킨스 의사입니다. 오늘 왜 오셨나...
# 1          train_1  #Person1#: 안녕하세요, 파커 부인, 어떻게 지내셨나요?\n#Person2#...
# 2          train_2  #Person1#: 실례합니다, 열쇠 한 묶음 보셨나요?\n#Person2#: 어떤...
# 3          train_3  #Person1#: 왜 너는 여자친구가 있다는 걸 말해주지 않았어?\n#Person...
# 4          train_4  #Person1#: 안녕, 숙녀분들! 오늘 밤 당신들은 정말 멋져 보여. 이 춤을 ...
# ...            ...                                                ...
# 12452  train_12455  #Person1#: 실례합니다. 맨체스터 출신의 그린 씨이신가요?\n#Person2...
# 12453  train_12456  #Person1#: 이윙 씨가 우리가 컨퍼런스 센터에 오후 4시에 도착해야 한다고 ...
# 12454  train_12457  #Person1#: 오늘 어떻게 도와드릴까요?\n#Person2#: 차를 빌리고 싶...
# 12455  train_12458  #Person1#: 오늘 좀 행복해 보이지 않아. 무슨 일 있어?\n#Person2...
# 12456  train_12459  #Person1#: 엄마, 다음 토요일에 이 삼촌네 가족을 방문하기 위해 비행기를 ...
#
#                                                  summary     topic
# ...

# %%
b = train[train['fname'].isin(low_end['fname'])]

# %%
low_end = b.copy()

# %%
low_end
# Out:
#              fname                                           dialogue  \
# 387      train_387  #Person1#: 헤이, 피터. 미안해.\n#Person2#: 안녕, 다이아나. ...
# 390      train_390  #Person1#: 자기야, 나 먼저 버그너스에 들려야 해. 좋은 물건들이 많아. ...
# 580      train_580  #Person1#: 왜 그렇게 소리 지르는 거야? \n#Person2#: 아미가 뜨...
# 789      train_789  #Person1#: 여권과 탑승 카드를 보여주십시오.\n#Person2#: 여기 있...
# 809      train_809  #Person1#: 오늘 오후에 시간이 있어요. 영화 보러 갈까요?\n#Person...
# ...            ...                                                ...
# 12082  train_12085  #Person1#: 저 여자분 보이세요? 그녀는 선생님인가요?\r\n#Person2...
# 12121  train_12124  #Person1#: 어느 날짜에 출발하시겠습니까, 선생님?\n#Person2#: 9...
# 12357  train_12360  #Person1#: 수잔나, 이 사진 좀 봐봐. 절벽 근처인데, 어디에서 찍었는지 ...
# 12358  train_12361  #Person1#: 음, 루시. 왜 그렇게 불행해보여?\n#Person2#: 오, ...
# 12428  train_12431  #Person1#: 맹세코, 제 다리가 부러진 것 같아요.\n#Person2#: 여...
#
#                                                  summary      topic
# ...

# %%
i = 19

# %%
i
# Out:
# 200

# %%
check = low_end.iloc[i]

print(check['fname'])
print('-' * 100)
print(check['summary'])
print('-' * 100)
print(check['dialogue'])
i += 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[320], line 1
# ----> 1 check = low_end.iloc[i]
#       3 print(check['fname'])
#       4 print('-' * 100)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1714, in _iLocIndexer._getitem_axis(self, key, axis)
#    1711     raise TypeError("Cannot index by location index with a non-integer key")
#    1713 # validate the location
# -> 1714 self._validate_integer(key, axis)
#    1716 return self.obj._ixs(key, axis=axis)
#
# ...

# %%
fnames.append(check['fname'])

# %%
fnames
# Out:
# ['train_6812',
#  'train_10900',
#  'train_10896',
#  'train_10897',
#  'train_830',
#  'train_7529',
#  'train_7551',
#  'train_7557',
#  'train_10062']

# %%
need_to_check = []

# %%
need_to_check.append(check['fname'])

# %% [markdown]
# 오류 종류
# 1. 반복
# 2. 뛰어쓰기 #person1 #
# 3. 사람이름 반복

# %%
need_to_check
# Out:
# []
