# %%
import pandas as pd
import re
import os
import platform

def extract_odd_sharp_sentence(text):
    # 개행으로 문장을 분리
    sentences = text.split('\n')
    
    # 샵(#)이 홀수 개수로 있는 문장을 추출
    odd_sharp_sentences = [sentence for sentence in sentences if sentence.count(':') > 1]
    
    return odd_sharp_sentences

def extract_odd_sharp_from_file(file_path):
    df = pd.read_csv(file_path)
    
    extracted_texts = []
    for index, row in df.iterrows():
        fname = row['fname']
        text = row['dialogue']
        odd_sharp_sentences = extract_odd_sharp_sentence(text)
        
        for sentence in odd_sharp_sentences:
            extracted_texts.append(f"{fname}: {sentence.strip()}")
    
    return extracted_texts

if __name__ == "__main__":
    os_name = platform.system()
    if os_name == 'Windows':
        PRE_PATH = ''
    elif os_name == 'Linux':
        PRE_PATH = '/kkh/'
    elif os_name == 'Darwin':  # 맥
        PRE_PATH = '/kkh/'

    DATA_PATH = PRE_PATH + "data/"
    file_path = DATA_PATH + 'train.csv'
    
    # 파일에서 샵(#)이 홀수 개수로 등장하는 문장을 추출하여 출력합니다.
    odd_sharp_texts = extract_odd_sharp_from_file(file_path)
    for text in odd_sharp_texts:
        print(text)
# Out:
# train_21: #Person2#: 응, 알고 있어. 티켓에 적힌 탑승 시간은 17:05이고, 지금은 16:15이야. 우리는 충분한 시간이 있는 것 같아.
# train_203: #Person2#: 로저스 씨: 네?
# train_203: #Person2#: 로저스 씨: 간호사실에 가보시겠어요?
# train_203: #Person2#: 로저스 씨: 여기 복도 통행증이 있어요. 누군가가 같이 가드릴까요?
# train_203: #Person2#: 로저스 씨: 나중에 상태를 확인하러 가볼게요.
# train_555: #Person2#: 그래요. 그녀가 그렇게 말했어요. 정확히 말하자면: '그들이 정확히 언제 등장했는지는 불확실하고... 그 이유는 아직 설명되지 않았다.'
# train_620: #Person1#: 구인 광고를 읽고 있었는데. 이건 너한테 딱이야. 구인: 새로운 레스토랑에서 웨이트리스를 찾습니다.
# train_651: #Person1#: ( 나중에 ) 여기 카드 있습니다, 선생님. 체크인이 모두 완료되었습니다. 저희 서비스에 대해 몇 가지 알려드리겠습니다. 7:00- 9:00 사이에 라운지에서 무료 아침 식사를 제공합니다. 리셉션에 전화하셔서
# train_661: #Person2#: 어떤 은행을 말씀하시는 건가요? 두 곳이 있습니다: 아일랜드 연합 은행과 아일랜드 은행.
# train_663: #Person3#: 첫 번째 질문: 고양이의 귀에는 각각 32개의 근육이 있습니다.
# train_663: #Person3#: 정답입니다! 두 번째 질문: 참치는 두 눈으로 깜박일 수 있는 유일한 물고기입니다.
# train_663: #Person3#: 정답입니다. 두 문제만 남았습니다. 세 번째 질문: 코끼리는 세상에서 가장 큰 눈을 가지고 있습니다.
# train_685: #Person2#: 네, 대부분의 상점들은 22:00이나 그 이전에 문을 닫지만, 인터넷은 하루 24시간, 일주일 내내 운영되며 어디서든 접속할 수 있어요.
# train_966: #Person1#: 표지판이 작동하는 한 곳을 알려드릴게요: 주차장이에요.
# train_1043: #Person2#: 그들이 사업을 운영하는 방법을 보세요: 지원자의 사진을 수집하고, 지원자가 그들의 성격 유형에 대해 작성할 설문지를 제공해요.
# train_1043: #Person2#: 봐요, 그들이 약속한 것입니다: 드림 데이트는 전문 데이트 서비스와 싱글들이 만날 수 있는 장소를 제공합니다. 우리는 당신의 파트너가 될 수 있는 유일하게 자격이 있는 사람을 소개해 드릴 것입니다.
# train_1289: #Person2#: 아니, 아니, 아니. 당신 말을 들어봐요. 당신은 피해자 행세를 하고 있어요. 당신은 잘못된 선택을 했고, 이제 그 결과를 받아들여야 합니다. 기억하세요: 당신이 다른 사람, 이 경우에는 저,를 가리키면 세 손가락이 당신을 가리키고 있습니다.
# train_1764: #Person2#: 성냥? 성냥은 물 웅덩이에 떨어뜨리면 끝장이에요. 적어도 세 가지 형태의 불 붙이는 도구를 챙겨야 해요: 돋보기, 고급 라이터, 그리고 방수 성냥.
# train_1856: #Person1#: 큰 컵에 모든 것을 조금씩 섞은 음료입니다: 펩시, 스프라이트, 환타 오렌지, 그리고 레몬에이드에 으깬 얼음과 아이스크림 한 스쿱이 들어있습니다.
# train_1856: #Person1#: 네, 고객님. 정말 더 작은 것을 원한다면 [네], 어린이 메뉴에서 주문하셔야 합니다: 반 파운드 슈퍼 핫 앤 스파이시 버거, 반 파운드 바베큐 버거, 반 파운드 베이컨 치즈 버거, 반 파운드 ...
# train_2016: #Person1#: 출발은 12:10에 하고 다음 날 15:10에 도착합니다.
# train_2049: #Person1#: 좋아. 첫 번째 질문: 하루에 담배를 열 개피 이상 피우나요?
# train_2049: #Person1#: 아니, 아니, 진짜로. 나도 그렇게 할 거야. 하지만 지금은 그렇다고 해야겠어. 좋아. 두 번째 질문: 일년에 한 번 이상 의사에게 검진을 받나요?
# train_2049: #Person1#: 그럼, 일곱 번째 질문으로 넘어가자: 하루에 열 시간 이상 일하나요?
# train_2049: #Person1#: 그게 그렇게 쉽지 않아. 마지막 질문: 당신은 살면서 걱정을 많이 하나요?
# train_2179: #Person2#: SW113편이 13:25에 출발합니다. 원하시나요?
# train_2572: #Person2#: 우리는 그들에게 3가지 선택을 제공했습니다: 3월 말, 4월 중순, 그리고 5월 초. 그리고 5월에 시험이 있으니 실제로 가장 빠른 시기를 선택했습니다.
# train_2762: #Person1#: A : 웹사이트에서 실시한 이 조사를 보세요. 직원들의 4분의 1이 매일 평균 10분씩 개인적인 일을 하기 위해 인터넷을 사용합니다. 프란시스씨, 당신은 어떠세요?
# train_2906: #Person2#: 먼저, 적절한 용품들이 필요합니다: 어떤 종류의 우리...
# train_3197: #Person1#: 19:00 기차를 원합니다.
# train_3197: #Person2#: 죄송합니다. 19:00 기차 티켓은 없습니다.
# train_3197: #Person2#: 다음 기차는 20:05에 출발합니다.
# train_3685: #Person2#: 들어봐: '세계에서 가장 빠르게 성장하는 회사 중 하나인 엑스코 수입 회사에 합류하세요.'
# train_3874: #Person1#: 물론입니다. 저희에게 전화하실 때 다음의 정보가 필요합니다. 운송장 주소: 아마도 당신의 주소겠죠? 그리고 픽업 주소. 그건 다릅니다. 그리고 연락 가능한 전화번호요.
# train_3875: #Person2#: 나는 개요를 써: 내가 하려는 말의 기본 계획이지. 그리고 나서 각 단락에 대한 주제로 그걸 채워. 그 후엔, 포함할 세부 사항에 대한 노트를 적는 거야.
# train_3918: #Person3#: 좋아, 내 독서용 안경을 찾아볼게. 좋아, 여기 있네. 규칙 번호 하나: 처음 6개월 동안은 친구들과 함께 운전하지 않는다.
# train_3918: #Person3#: 응. 어디까지 얘기했지? 아, 그래. 규칙 번호 둘: 항상 안전 벨트를 착용하고 도로 규칙을 준수해야 한다.
# train_3918: #Person3#: 좋아, 규칙 번호 셋: 밤에 장거리를 운전하면 졸릴 수 있으니까 그런 건 안 돼. 하지만 영화관까지 운전하는 건 괜찮아.
# train_3918: #Person3#: 그리고 규칙 번호 넷: 운전 중에는 절대로 휴대폰을 사용하면 안 돼. 사고가 날 수 있다고.
# train_3918: #Person3#: 그리고 규칙 번호 다섯: 나는 너를 사랑하고, 그냥 네가 항상 안전하길 바라고 널 보호하려는 아빠일 뿐이야.
# train_4703: #Person1#: 잠시만요. 그 비행기는 내일 14:00에 출발합니다. 가격은 110달러입니다.
# train_4911: #Person1#: 잠시만 기다려 주세요. . . 네. 16:45와 18:00에 있습니다.
# train_4911: #Person2#: 16:45 비행기로 부탁합니다.
# train_4911: #Person1#: 예약이 완료되었습니다, 존스씨. 비행기는 16:45에 출발하며 시드니 도착은 현지 시간 오전 9시입니다. 항공편 번호는 NWA 476입니다.
# train_5017: #Person1#: 하지만 한 가지: 그것이 개인적으로 느껴지지 않나? 나는 수업 토론을 하고 다른 사람들이 무엇을 생각하는지 듣는 것이 그립다는 말이야.
# train_5219: #Person1#: 아, 세 마법의 단어: 도움이 필요해! 이전에 들어본 적이 있어.
# train_5258: #Person2#: 면접 같은 경우요. 이 사진을 보세요: 여기에 면접을 보는 사람이 있어요. 면접이 스트레스 받는다고 생각하나요?
# train_5594: #Person2#: 흠. 그건 출생증명서를 요구하는 이유가 될 수 없어요. 우리는 거주지를 확인하기만 하면 돼요: 당신의 이름과 주소가 적힌 전화 요금 청구서면 충분했을 거예요.
# train_6103: #Person1#: 내가 정말 좋아하는 코미디 작품 알아? '에이스 벤츄라: 애완동물 탐정'이야. 나는 짐 캐리가 정말 웃겨.
# train_6554: #Person2#: 여기 있습니다: 홍콩 달러, 미국 달러, 그리고 일본 엔. 이것들은 영국 파운드로 얼마나 되나요?
# train_6586: #Person2#: 일반적으로, 골프 클럽 세트는 3, 4, 5, 6, 7, 8, 9, PW; 우즈: 1, 3, 5 그리고 퍼터로 구성됩니다.
# train_6609: #Person1#: 아니. 잊어. 네가 경찰에게 문자하거나 전화하는 게 좋을 시간인 것 같아. 남자: 아악.
# train_6750: #Person2#: 그리고 마지막으로, 새로운 옷장을 원해: 새 드레스, 셔츠, 바지, 귀걸이...
# train_6810: #Person2#: 고마워, 가일, 하지만 난 적합한 동승자 찾았어: 고메즈 씨. 그녀가 다음 주에 내 아파트 근처로 이사 올 예정이야. 그래서, 같이 타기에 편리할 거야.
# train_6827: #Person1#: 선생님: 내일은 12페이지부터 20페이지까지 읽고, 21페이지에 있는 1번부터 10번까지의 연습문제를 풀어오세요.
# train_6827: #Person1#: 선생님: 아니요. 보고서를 작성할 때만 그렇게 하세요.
# train_6827: #Person1#: 선생님: 계산기가 없는 학생들은 가져오세요.
# train_6827: #Person1#: 선생님: 네. 그리고 오늘 저녁에 노트에 복습하세요. 내일 간단하게 퀴즈를 낼 수도 있습니다.
# train_6849: #Person2#: 네, 많이 갔어요. 저는 전시회를 좋아해요-유명한 사람들에 대한 전시회를 말이에요: 댄서, 배우, 알죠?
# train_6953: #Person2#: 알겠습니다, 여기 도착했습니다, 아가씨. 오페라 하우스에 17:25이네요.
# train_7281: #Person1#: 현재 미국 달러와 위안화의 환율은 1:8.3입니다. 손님이 저에게 100달러 수표 두 장을 주셨으니, 여기 1,660 위안이 있습니다. 맞나요?
# train_7325: #Person2#: 네. 저는 정말로 심한 무대 공포증을 겪어요. 그런데 교실에 들어오거나 무대에 오르는 순간 모든 게 딱 맞아떨어지더라고요. 그런 다음 저는 그냥 이렇게 느껴요: 그래, 이게 바로 제가 해야 할 일이야. 그리고 저는 괜찮아져요.
# train_7368: #Person1#: 알았어, 고마워. 남자: 고마워.
# train_7417: #Person1#: 제니, 이걸 기억해: 제대로 할 만한 가치가 있는 일은 잘 할 가치가 있다.
# train_7567: #Person1#: 물론입니다. 호틴, 데니스. 출생: 1836년 달링턴; 사망: 1920년 뉴욕.
# train_7614: #Person2#: 그럼요: 1982년에 뉴햄프셔에서 산악 등반을 하고 있었어요. 갑자기 날씨가 정말 나빠졌어요. 눈이 많이 와서 아무것도 볼 수 없었어요. 그래서 우리는 길을 잃었어요. 그래서, 우리는 산에서 4일을 보냈어요. 기온은 -20도였어요. 우리는 장비나 음식이 전혀 없었어요.
# train_7662: #Person2#: 뭐? 이제 또 뭐야? 큰 자아, 작은 귀: 남편을 구름 위에서 내리게 하는 방법. 이게 뭐야? 뭐? 그리고 이걸 $35도 주고 샀어?
# train_7664: #Person2#: 그리고 한 가지 더: 매달 전화요금을 납부하는 것을 잊지 마세요!
# train_7810: #Person2#: 첫 번째 질문: 얼마나 자주 약을 복용하시나요?
# train_8001: #Person1#: 그러면 7월 13일이네요. 그날 두 번의 비행기가 있습니다: 하나는 오전 9시, 다른 하나는 오후 3시 30분입니다.
# train_8149: #Person2#: 음, 했어, 거기, 뭐, 너 ... 그것은 ... 그 남자가 할 수 없는 것을 했어. [번역: 그것은 하지 말아야 할 것을 했어.]
# train_8301: #Person1#: 안녕 필: 일본의 공중 목욕탕에 가 본 적 있니? 꽤 좋은 경험인 것 같던데.
# train_8437: #Person1#: 알겠습니다. 이제 가장 중요한 질문입니다: 사람들과 함께 일하는 것을 좋아하나요? 호텔에서는 하루 종일 사람들과 일해야 합니다.
# train_8687: #Person1#: 그래! 도착했어. 5:58, 도서관 문 닫기 직전이야.
# train_9074: #Person1#: 하지만 가장 흥미로운 결과는 이거야: 그들 중 오직 한 명만이 책을 읽어.
# train_9223: #Person1#: 당신이 좋아하는 것: 버섯과 양파가 들어간 계란후라이와 소시지입니다. 테이블을 차려주고 커피를 내려주시겠어요? 음식은 10분 후에 준비될 거예요. 아, 접시를 세 개 놓아주세요. 아침식사에 손님이 오거든요.
# train_9703: #Person2#: 이런 일이 생겨서 정말 죄송합니다. 어떻게 보상해드릴까요: 오늘 스프 값은 제가 내겠습니다.
# train_9873: #Person1#: 선생님: 너 매리 린이지?
# train_9873: #Person1#: 선생님: 나는 로저스 선생님, 너의 담임 선생님이야.
# train_9873: #Person1#: 선생님: 브래드 뒤에 앉는 건 어때?
# train_9873: #Person1#: 선생님: 파란 셔츠를 입은 그 남자야.
# train_9873: #Person1#: 선생님: 아침 방송 후 종이 울리면 바로 시작돼.
# train_9937: #Person1#: B :: 미아오 앙! 그 목소리는 어디서나 알아볼 수 있습니다. 무엇을 도와드릴까요? 문제가 있나요?
# train_10084: #Person1#: 항상 타협점이 있습니다: 바깥 도로와 뒤쪽에 있는 공항 때문에 조금 시끄럽지만, 바로 건너편에 슈퍼마켓과 쇼핑 센터가 있어서 매우 편리합니다. 창문을 닫고 귀마개를 준비해두면 괜찮을 것입니다.
# train_10567: #Person1#: 마지막으로 한마디: 잡초 퇴치제를 숨기세요. [하지만 ...] 고마워요, 마크. 지금은 이만 시간을 마치겠습니다. 다음 전화를 받아보겠습니다.
# train_10769: #Person1#: 좋아. 그럼 생일 축하 노래를 불러볼까: 생일 축하합니다, 생일 축하합니다, 사랑하는 마이클, 생일 축하합니다. 좋아. 그럼 먼저 무엇을 할까?
# train_11001: #Person1#: 레니, 이 말을 어떻게 해야 할지 모르겠지만, 그냥 말하겠습니다: 오늘 아침에 당신의 고양이를 잃어버렸어요.
# train_11241: #Person2#: 네, 저는 사람들을 많이 관찰합니다. 여행을 할 때 그렇게 합니다. 저는 영국, 이탈리아, 스웨덴 등 많은 나라를 다녀왔습니다. 그래서 공항에서 많은 시간을 보냅니다. 비행기를 기다리는 동안, 지나가는 사람들을 보며 상상력을 키웁니다. 예를 들어, 그날 그리스로 가는 비행기를 기다리고 있을 때, 한 커플을 봤습니다. 그들은 그 순간 잡지를 사고 있었습니다. 그들은 비즈니스 복장을 입고 있지 않았지만, 남자는 여행 가방을 들고 있었습니다. 여자는 몇 초마다 주위를 둘러봤습니다. 누군가 그들을 따라오고 있는 것 같았습니다. 아마도 그들은 도망치고 있는 것일지도 모릅니다. 그리고, 이것은 그날 신문에 나온 이야기를 생각나게 했습니다: 은행 직원이 일주일 전에 백만 파운드를 훔쳐 그의 아내와 함께 사라졌습니다. 신문에 그들의 사진이 있었습니다. 그 커플은 정말로 그 사진 속의 사람들처럼 보였습니다. 아마도 저는 그들을 막아야 했을지도 모릅니다. 그때, 그들이 서로 작별 인사를 하고, 여자가 걸어가는 것을 봤습니다. 음, 가끔 저는 그런 실수를 합니다. 하지만 저는 그런 것들이 내 글쓰기에 매우 유용하다고 생각합니다.
# train_11244: #Person2#: 음, 이것 뿐입니다 : 월요일 오후 5시에 회의에 참석할 수 있을까요?
# train_11386: #Person2#: 나는 이렇게 하는 게 좋을 것 같아: 지금 책값을 반반 나눠서 내.
# train_11440: #Person1#: 한번 볼게요. 여기 있네요. 콜롬비아: 인 더 월드. 모든 청소년들이 꼭 봐야 하는 영화래요.
# train_11440: #Person1#: 센트럴: 칠드런스 월드. 청소년 자녀를 둔 모든 부모님들이 이 영화를 봐야 한다네요.
# train_12111: #Person2#: 이렇게 하는 게 더 좋을 것 같아요: 지금 책에 대해 반반씩 비용을 나눠서 내고, 과정이 끝날 때에는 각자 흥미로운 책을 가져가요.
# train_12159: #Person1#: 어떻게 보면: 이번 주 말에 어차피 짐에게 전화를 걸테니까, 그에게 얘기해볼게요.
