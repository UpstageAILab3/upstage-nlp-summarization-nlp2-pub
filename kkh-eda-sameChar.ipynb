# %% [markdown]
# ## 연속된 두 글자(train)
#
# - 멀쩡한 '연속된 두 글자'는 예외 리스트에 추가하면서 계속 찾고 있지만, 너무 많고, 잘 못되어 보이는 '연속된 두 글자'가 없는 듯 하여, '연속된 세 글자'로 넘어감.

# %%
import pandas as pd
import re

def find_repeated_hangul(file_path, excluded_words):
    df = pd.read_csv(file_path)
    
    if 'dialogue' not in df.columns:
        raise ValueError("'dialogue' 열이 CSV 파일에 없습니다.")
    
    # 한글 자음과 모음의 유니코드 범위 정의
    repeated_hangul_pattern = re.compile(r'([가-힣])\1{1,}')
    
    results = []

    for _, row in df.iterrows():
        fname = row['fname']
        dialogue = row['dialogue']
        
        # 문장 단위로 분리
        sentences = dialogue.split('\n')  # 각 문장은 줄바꿈으로 구분된다고 가정

        for sentence in sentences:
            # 연속된 동일 한글 글자를 찾기 위한 정규 표현식
            repeated_hangul = re.findall(repeated_hangul_pattern, sentence)
            
            # 연속된 한글이 발견되었고, 제외할 단어가 포함되지 않은 경우
            if repeated_hangul and not any(excluded_word in sentence for excluded_word in excluded_words):
                results.append((fname, sentence))
    
    return results

if __name__ == "__main__":
    import platform
    
    os_name = platform.system()
    if os_name == 'Windows':
        PRE_PATH = ''
    elif os_name == 'Linux':
        PRE_PATH = '/kkh/'
    elif os_name == 'Darwin': # 맥
        PRE_PATH = '/kkh/'

    DATA_PATH = PRE_PATH + "data/"
    file_path = DATA_PATH + 'train.csv'  # 또는 'dev.csv'로 변경 가능
    
    excluded_words = ["몇몇", "멋지지", "각각", "내내", "천천히", "다다른", "종종", "뭔가가", "누군가가", "일일", "때때로", "축하하는지", "다가가면", "상상도", "상상해", "점점", "똑똑한", "뻣뻣", "부부", "강의의", "사업가가", "돌아서서", "방해해서", "튼튼", "이해해", "아니니", "지지력"]
    
    # 연속된 동일 한글 찾기
    repeated_hangul_results = find_repeated_hangul(file_path, excluded_words)
    
    # 결과 출력
    if repeated_hangul_results:
        for fname, sentence in repeated_hangul_results:
            print(f"File: {fname}")
            print(f"Sentence: {sentence}")
            print("-" * 40)
    else:
        print("No repeated Hangul characters found.")
# Out:
# File: train_92
# Sentence: #Person1#: 썬샤인 호텔입니다. 좋은 아침입니다, 바바라입니다.
# ----------------------------------------
# File: train_93
# Sentence: #Person1#: 안녕하세요, 바바라님. 다시 오신 것을 환영합니다. 정말 멋져 보입니다.
# ----------------------------------------
# File: train_93
# Sentence: #Person1#: 바바라님, 가방 안에 뭐가 들어있나요? 책이나 돌이라도?
# ----------------------------------------
# File: train_96
# Sentence: #Person2#: 하하, 친구를 위해서라면 언제든 시간을 내줄 수 있어, 오늘 밤 어때?
# ----------------------------------------
# File: train_141
# Sentence: #Person1#: 매우 즐거웠어요. 이번이 제가 가본 여행 중에서 가장 흥미진진했던 여행 중 하나였어요. 이번이 중국에 오신 첫 여행이었나요?
# ----------------------------------------
# File: train_172
# Sentence: #Person1#: 린다, 그건 완벽한 추가가 될 것 같아요.
# ----------------------------------------
# File: train_177
# Sentence: #Person2#: 흥분하지 마세요, 제 개인적인 상상일 뿐입니다!
# ----------------------------------------
# File: train_192
# Sentence: #Person1#: 네, 그것은 21%를 차지합니다. 또한 외국어를 쓸모없다고 생각하고 전혀 관심을 가지지 않는 사람들도 약 15% 있습니다.
# ----------------------------------------
# File: train_201
# Sentence: #Person2#: 당신의 나라에서는 자주 일어나나요?
# ----------------------------------------
# File: train_202
# Sentence: #Person2#: 그래, 그런데 뭐 어때요! 저는 세계에서 가장 흥미진진한 도시에 살고 있다는 것이 자랑스러워요. 그리고, 여기는 전국에서 가장 높은 급여를 받는 곳이기도 하죠.
# ----------------------------------------
# File: train_214
# Sentence: #Person1#: 저요? 우리 저녁을 요리하다니요? 하하! 요리는 당신이 할 거예요. 당신이 요리할 거예요.
# ----------------------------------------
# File: train_237
# Sentence: #Person1#: 사람들이 그런 일을 막을 만큼 똑똑하다고 생각할 것 같죠. 아무도 그의 오토바이가 도난당하고 있다는 것을 몰랐어요. 도둑들은 트럭으로 와서 모두에게 제 삼촌이 불법 주차를 했고, 그들이 그것을 견인하러 왔다고 설득했어요.
# ----------------------------------------
# File: train_246
# Sentence: #Person1#: 그럼요, 최근에 저는 미국에서 그레인저스 고메 본본의 독점 유통업자가 되었습니다. 그들은 새로운 제조업체로서 명품 시장에 진출하려고 합니다. 당연히, 당신의 레스토랑이 바로 제 머릿속에 떠올랐어요. 저는 당신의 브랜드가 그레인저스와 많은 공통점을 가지고 있으며, 이 초콜릿을 제공하면 당신의 우아하고, 고급스럽고, 일류의 식사 제공에 대한 평판을 더욱 높일 것이라고 생각합니다.
# ----------------------------------------
# File: train_246
# Sentence: #Person1#: 그레인저스 가족이 대대로 전해 내려온 전통적인 비밀 레시피라는 것을 최고의 권위자에게서 들었습니다. 저는 당신이 비밀을 지킬 수 있을 거라 확신합니다. 버터밀크, 카카오 콩, 설탕 그리고 헤기스입니다.
# ----------------------------------------
# File: train_261
# Sentence: #Person1#: 맞아요. 회의의 의장이 될 예정이니, 제가 통제불능이 되는 것을 원하지 않아요.
# ----------------------------------------
# File: train_264
# Sentence: #Person1#: 그렇게는 어디에도 도달할 수 없어요. 영어 연습이 필요한 사람은 당신이니까, 당신이 먼저 다가가야 해요. 게다가, 대부분의 미국 학생들은 정말 친절하고 외향적이에요. 그들은 당신과 이야기하는 것을 기뻐할 거예요.
# ----------------------------------------
# File: train_269
# Sentence: #Person2#: 제 장기적인 목표는 이 분야에서 전문가가 되는 것입니다.
# ----------------------------------------
# File: train_276
# Sentence: #Person1#: 헤이, 그게 뭐예요? [아아아!]
# ----------------------------------------
# File: train_278
# Sentence: #Person2#: 대부분의 보도는 모서리에서 평평하게 만들어진 것 같아서, 아마 너의 휠체어를 사용할 수 있을 거야, 하지만 확실하지 않아. 사실, 너가 원한다면, 나와 같이 가지 않을래? 나는 버스를 타고 갈 텐데, 우리가 도착하면 너에게 주변을 보여줄 수 있어.
# ----------------------------------------
# File: train_285
# Sentence: #Person2#: 그게 좋은 생각 같지 않아. 나는 그냥 누군가에게 다가가서 대화를 시작하는 것이 잘 안돼.
# ----------------------------------------
# File: train_285
# Sentence: #Person1#: 자, 그냥! 여자에게 다가가서 '너가 코딱지라면 나는 너를 먼저 고를 거야.'라고 말하면 돼.
# ----------------------------------------
# File: train_285
# Sentence: #Person2#: 뭐라고? 자, 그건 그냥 뻔뻔한 말이야! 그런 말에 여자가 넘어갈리가 없어!
# ----------------------------------------
# File: train_286
# Sentence: #Person2#: 미안해요, 대부에서 나온 대사예요. 영화 제작자가 톰 히긴스가 비토 코를레오네의 사절이라는 걸 깨닫는 장면이죠. 말의 머리가 피투성이의 침대에 나타나기 바로 전에요, 아시죠, 깨어나서 아아! 아무튼.
# ----------------------------------------
# File: train_321
# Sentence: #Person1#: 왜 작가가 되기로 결정하셨나요?
# ----------------------------------------
# File: train_321
# Sentence: #Person2#: 아마도 쓸 수도 있겠네요. 하지만 저는 글을 쓸 때 대상 독자를 상상하지 않아요. 아이디어가 먼저에요. 그래서 정말로 다음에 저를 사로잡는 아이디어에 달려있어요.
# ----------------------------------------
# File: train_324
# Sentence: #Person1#: 와! 너 정말 똑똑하다! 사실, 나도 그 가게에서 멋진 모자를 오랫동안 눈여겨 보고 있었어. 가격을 내릴 수 있게 도와줄 수 있을까?
# ----------------------------------------
# File: train_339
# Sentence: #Person1#: 세계 곳곳에서 다양한 경험을 하셨군요.
# ----------------------------------------
# File: train_341
# Sentence: #Person1#: 500위안을 인출하면 5000위안이 나오면 얼마나 좋을까요! 하하, 참 좋겠네요!
# ----------------------------------------
# File: train_348
# Sentence: #Person2#: 그리고 정말 재미있어요. 어느 날, 몸들이 너무 밀집되어서 어떤 여자의 엉덩이가 제 앞에 붙어 있었어요. 실수로 그녀를 만지지 않으려고 손을 내리지 않으려고 애썼어요.
# ----------------------------------------
# File: train_349
# Sentence: #Person1#: 만약 당신이 나비에 관심이 있다면, 반드시 나비 전시회를 가봐야 해요. 개인 박물관의 주인인 첸 씨는 20개 이상의 국가에서 수집한 1,000여 종의 나비 표본을 대중에게 전시하고 있어요. 그 중 상당수는 국가급 보물입니다.
# ----------------------------------------
# File: train_352
# Sentence: #Person2#: 음, 잠깐만, 로맨스, 코미디. 다큐멘터리, 액션, 공상과학, 애니메이션 등등.
# ----------------------------------------
# File: train_359
# Sentence: #Person1#: 그래, 아이가 문제야. 진실을 제니에게 말하지 마, 그녀에게는 선의의 거짓말만 해. 그녀가 성장하면 적절한 기회를 찾아서 말해주면 돼.
# ----------------------------------------
# File: train_361
# Sentence: #Person2#: 어떤 종류의 중개인인가요?
# ----------------------------------------
# File: train_361
# Sentence: #Person1#: 텔레마케팅 분야야.
# ----------------------------------------
# File: train_361
# Sentence: #Person2#: 그분이 수수료를 요구했어?
# ----------------------------------------
# File: train_362
# Sentence: #Person1#: 그게 바로 인기의 비결이야. 이 노래는 바바라 투틴이 녹음했어. 그녀가 개막일에 이 노래를 무대에서 부르자 큰 화제가 됐다고 들었어.
# ----------------------------------------
# File: train_363
# Sentence: #Person1#: 면도도 하시겠어요, 선생님.
# ----------------------------------------
# File: train_392
# Sentence: #Person2#: 디저트로 과일을 먹을 수 있어. 사과와 바나나를 먹으면, 작은 조각의 초콜릿 케이크를 먹을 수 있게 해줄게.
# ----------------------------------------
# File: train_399
# Sentence: #Person2#: 괜찮을 것 같아요. 사실, 당신의 생일을 함께 축하하는 것이 기쁠 것 같아요. 몇 시에 시작하려고 하나요?
# ----------------------------------------
# File: train_429
# Sentence: #Person1#: 그럼. 나는 이걸 TV에서 들었어. 2004년 1월 3일, 탐사선 스피릿이 소위 구세프 크레이터 근처에 착륙했어. 그리고 3주 후에, 스피릿의 쌍둥이 탐사선인 오퍼튜니티가 과학자들이 명명한 메리디아니 플라눔에 착륙했지.
# ----------------------------------------
# File: train_430
# Sentence: #Person1#: 미리 티켓을 예매한 것 정말 똑똑하네요!
# ----------------------------------------
# File: train_431
# Sentence: #Person2#: 그건 공공연한 비밀이죠.
# ----------------------------------------
# File: train_440
# Sentence: #Person1#: 열은 나나요?
# ----------------------------------------
# File: train_444
# Sentence: #Person1#: 제 개인적으로는 절대 원하지 않지만, 임신이 여성의 전체 생활에 영향을 미치므로 그녀가 스스로 결정할 권리가 있어야 한다고 생각해요.
# ----------------------------------------
# File: train_458
# Sentence: #Person1#: 항상 든든한 아침식사를 해야 해.
# ----------------------------------------
# File: train_460
# Sentence: #Person2#: 아아아아아아
# ----------------------------------------
# File: train_460
# Sentence: #Person1#: 하하, 물론입니다! 여기 있습니다. 이제 가서 침대에서 쉬세요. 궁금한 점이 있으면 언제든지 전화주세요! 빨리 나아지시길 바라고, 건강하세요.
# ----------------------------------------
# File: train_469
# Sentence: #Person2#: 추가 비용이나 수수료 같은 것이 있나요?
# ----------------------------------------
# File: train_469
# Sentence: #Person1#: 서비스 수수료를 지불해야 합니다. 그것은 송금할 금액의 1%이며, 따라서 추가로 6위안을 지불해야 합니다.
# ----------------------------------------
# File: train_522
# Sentence: #Person2#: 그래, 처리해야 할 일이 많아---결혼 사진, 웨딩드레스, 케이터링, 교통, 호텔 등등...
# ----------------------------------------
# File: train_524
# Sentence: #Person1#: 투자자들과의 점심 회의를 위해 레스토랑에 예약을 해야 하나요, 아니면 그냥 가면 되나요?
# ----------------------------------------
# File: train_524
# Sentence: #Person2#: 투자자들에게 풀 코스 식사를 대접하려고 계획하고 계신 건가요?
# ----------------------------------------
# File: train_535
# Sentence: #Person2#: 이곳은 공공 코트라 누구든 여기에 들어올 수 있습니다. 좀 더 조심하셔야 합니다.
# ----------------------------------------
# File: train_540
# Sentence: #Person1#: 그럼 시험에 떨어지지 않으려면 더 열심히 일했어야 했어. 일하면서 공부해야 해.
# ----------------------------------------
# File: train_541
# Sentence: #Person2#: 먼저, 그녀는 근면해야 하며, 두 번째로는 그녀가 스스로 많은 일을 해야 한다는 점입니다. 마지막으로, 그녀는 속기로 노트를 작성하고 타이핑을 하며 보고서 작성, 요약 작성, 회의록 작성 등의 기술을 갖추고 있어야 합니다. 가장 중요한 것은 그녀가 평균보다 더 좋은 기억력을 가지고 있는 것 같다는 것입니다.
# ----------------------------------------
# File: train_547
# Sentence: #Person2#: 네, 하지만 물건을 찾는 데는 시간이 좀 걸립니다. 일반 상점처럼 꼼꼼하게 정리되어 있지 않아요.
# ----------------------------------------
# File: train_553
# Sentence: #Person2#: 우리 둘 중 어느 쪽도 자신의 가격을 고집하는 것은 현명하지 않다고 생각합니다. 어떻게 보면 서로 반반씩 양보하여 사업을 마무리하는 것이 어떨까요?
# ----------------------------------------
# File: train_553
# Sentence: #Person2#: 당신의 단위 가격이 우리가 받아들일 수 있는 것보다 100달러 높습니다. 저는 우리가 반반씩 양보하자는 것을 말 그대로 의미했습니다.
# ----------------------------------------
# File: train_553
# Sentence: #Person2#: 그래도 20달러의 차이가 남아 있습니다. 한 번 더 반반씩 양보하면 차이가 없어지고 우리의 사업이 완료될 것입니다.
# ----------------------------------------
# File: train_553
# Sentence: #Person1#: 당신은 정말로 나를 설득하는 방법을 알고 있군요. 좋습니다, 다시 반반씩 만나봅시다.
# ----------------------------------------
# File: train_553
# Sentence: #Person1#: 네, 그렇습니다. 오늘 밤에 본사에 전화해서 알려야겠습니다. 다음에 언제 만나나요?
# ----------------------------------------
# File: train_555
# Sentence: #Person1#: 어떤 오징어는 정말 크더라고요. 그것이 아직 껍질이 있다면 얼마나 크게 상상할 수 있을까요?
# ----------------------------------------
# File: train_555
# Sentence: #Person2#: 그렇게까지는 아니었어요. 하지만 그녀는 몇 가지 특이한 사례를 언급했어요. 1933년에 뉴질랜드에서 잡은 오징어가 있었는데.. 여기 보세요.. 그것은 22야드 길이였어요. 눈은 18인치였어요. 상상할 수 있나요?
# ----------------------------------------
# File: train_555
# Sentence: #Person2#: 심슨 박사는 오징어가 똑똑하고 빠르기 때문에 아마도 더 큰 것들이 발견되지 않았을 것이라고 생각해요---그래서 그들은 사람들로부터 쉽게 도망칠 수 있어요. 아마 그 괴물 이야기 중 일부는 사실일 수도 있어요.
# ----------------------------------------
# File: train_592
# Sentence: #Person1#: 혈압을 재 보겠습니다. 피부색이 창백해 보이네요. 그런데, 브라운 씨. 다행히도 별것 아닙니다. 그저 과로로 인해 조금 지쳤을 뿐이에요.
# ----------------------------------------
# File: train_611
# Sentence: #Person1#: 그래요, 가야 했을 거예요. 정말 흥미진진했어요.
# ----------------------------------------
# File: train_626
# Sentence: #Person2#: 모르겠어요. 그건 어려운 질문이에요, 왜냐하면 기자가 너무 많거든요. 신문에 실린 이야기들은 대체로 정확하긴 하지만, 불행히도 일부 사람들은 공공의견에 영향을 미치기 위해 거짓 정보를 유출하기도 해요. 그래서 그 뉴스 이야기가 왜 공개되었는지 고려해야 해요.
# ----------------------------------------
# File: train_652
# Sentence: #Person1#: 수수료로 10위안을 내주시기 바랍니다.
# ----------------------------------------
# File: train_653
# Sentence: #Person1#: 사실 저는 명품 제품을 피하려고 노력합니다. 대기업들이 제품을 곳곳에 광고하는 것을 참을 수 없어요!
# ----------------------------------------
# File: train_673
# Sentence: #Person2#: 내 주인공들은 살아있는가?. 그들은 스스로 생각해요. 그들의 모든 이야기는 삶에서 끌어온 것이다, 내 삶, 내 친구들의 삶, 그리고 많은 책들 속의 친구들을 포함해서.
# ----------------------------------------
# File: train_680
# Sentence: #Person1#: 그냥 일반적인 딱딱한 솔털 칫솔을 사용해요.
# ----------------------------------------
# File: train_681
# Sentence: #Person1#: 아, 네, 제 딸이 어제 샀어요. 우리는 그녀를 루루라고 부릅니다.
# ----------------------------------------
# File: train_681
# Sentence: #Person1#: 아마 루루에게 몇 가지 영어 단어를 가르쳐 줄 수 있을 거예요.
# ----------------------------------------
# File: train_681
# Sentence: #Person2#: 루루. 루루. 인사해봐. 안녕. 오, 정말 똑똑하네요. 참 잘했어요, 귀여운 새야.
# ----------------------------------------
# File: train_685
# Sentence: #Person1#: 좋아 보이네요, 그리고 저는 계산대에서 줄을 서서 기다릴 필요도 없겠네요.
# ----------------------------------------
# File: train_687
# Sentence: #Person1#: 우리의 파운데이션은 매우 고급 품질입니다. 최고급 재료만을 사용합니다. 피부를 촉촉하게 해주며 UVA와 UVB로부터 피부를 보호해줍니다.
# ----------------------------------------
# File: train_689
# Sentence: #Person1#: 우리는 이 문제를 천 번이나 논의했습니다. 이 데이터는 부정할 수 없어요! 봐요, 우리는 광범위한 연구를 했고, 연구를 수행하고, 문헌을 읽었고, 내 이론을 지지하는 결정적인 증거가 있습니다!
# ----------------------------------------
# File: train_707
# Sentence: #Person1#: 먼저, 컴퓨터 프로그래머로 일을 구하고 싶고, 그리고 5년 정도 후에는 내 스스로의 사업을 시작하고 싶어.
# ----------------------------------------
# File: train_712
# Sentence: #Person2#: 그게 중요한 문제가 아닙니다. 캠페인은 두 가지 중요한 무역 행사를 놓쳤습니다. 이것 때문에 우리는 내년에 캠페인을 무료로 반복하거나, 올해의 수수료를 50%만 지불하도록 요청하고 있습니다.
# ----------------------------------------
# File: train_712
# Sentence: #Person1#: 수수료를 20% 줄이고 캠페인을 4주 연장하는 것을 제안해도 될까요?
# ----------------------------------------
# File: train_712
# Sentence: #Person2#: 좋아요, 새로운 해결책을 제안해봅시다. 수수료를 40% 줄이거나, 무료로 캠페인을 반복하는 것은 어떨까요?
# ----------------------------------------
# File: train_732
# Sentence: #Person2#: 우리가 부엌을 확인해봐야 할 것 같아요. 넓고 넉넉하다고 광고에 나와있거든요.
# ----------------------------------------
# File: train_735
# Sentence: #Person2#: 가슴이 답답해서 어려움이 있었습니다. 이에 대한 몇 가지 테스트를 해볼 수 있나요?
# ----------------------------------------
# File: train_735
# Sentence: #Person1#: 가슴 X-선을 찍어 답답함을 확인할 수 있습니다.
# ----------------------------------------
# File: train_747
# Sentence: #Person2#: 오, 저는 텔레비전에서 봤어요. 정말 흥미진진한 경기였어요.
# ----------------------------------------
# File: train_749
# Sentence: #Person2#: 하지만 환불 수수료를 지불해야 합니다.
# ----------------------------------------
# File: train_753
# Sentence: #Person1#: 축하해요, 비비안. 또 대상을 받았네요.
# ----------------------------------------
# File: train_760
# Sentence: #Person2#: 어떤 면에서는 그렇습니다. 하지만 기억을 사용하는 연습을 할 수도 있는데, 이는 뇌를 운동시키는 것뿐만 아니라 기억하는 능력을 향상시키는 데도 도움이 됩니다. 불행히도, 현대 생활에서 많은 기기들은 우리가 무언가를 잊지 않도록 설계되어 있어, 우리의 뇌를 더 게으르게 만들고 기억력을 약화시킬 수 있습니다.
# ----------------------------------------
# File: train_761
# Sentence: #Person2#: 삼모사와 파파돔 중에 어떤 걸 더 좋아하시나요?
# ----------------------------------------
# File: train_762
# Sentence: #Person2#: 음, 잠깐만. 로맨스, 코미디, 다큐멘터리, 액션, 공상과학, 애니메이션 등등.
# ----------------------------------------
# File: train_768
# Sentence: #Person2#: 아니요, 보통 서서 가야 합니다.
# ----------------------------------------
# File: train_770
# Sentence: #Person2#: 흥미롭네요. 생각해보니, 저는 터키의 스텀블에서 여행할 때 지나친 것 같아요. 와, 정말로 전 세계 곳곳에 있는 거군요.
# ----------------------------------------
# File: train_782
# Sentence: #Person2#: 제 남편과 저는 아이를 가지지 않기를 선호하는데, 제 시어머니는 매우 전통적이어서 손자를 원해요.
# ----------------------------------------
# File: train_782
# Sentence: #Person2#: 그럴 수도 있겠네요. 하지만 저는 여전히 아이를 가지지 않는 것을 선호해요.
# ----------------------------------------
# File: train_797
# Sentence: #Person2#: 보통 그 나라의 대사관이나 영사관에 전화할 수 있어. 대부분의 경우, 비즈니스 방문객을 위한 인쇄 자료가 있어. 그리고 공공 도서관에서도 여행 서적을 구할 수 있어. 시간이 충분하지 않다면, 지난번에 그곳에서 회의에 참석한 샐리에게도 물어볼 수 있어.
# ----------------------------------------
# File: train_807
# Sentence: #Person1#: 오늘 스튜디오에는 알베르토 코르테즈, 잘 알려진 브라질의 반세계화 운동 지지자가 함께하고 있습니다. 그는 2050년까지 브라질이 세계에서 가장 부유하고 성공적인 나라 중 하나가 될 것이라는 최근 보고서에 대해 이야기하러 왔습니다. 알베르토, 이 보고서에 대해 어떻게 생각하십니까?
# ----------------------------------------
# File: train_808
# Sentence: #Person2#: 아니, 아직은 없어. 요즘 모두가 작가가 되고 싶어하는 것 같아. 그래서 일자리가 별로 없어.
# ----------------------------------------
# File: train_809
# Sentence: #Person2#: 음, 대부분의 연극은 잘 쓰여지지 않았지만, 가격은 싸요.
# ----------------------------------------
# File: train_825
# Sentence: #Person2#: 나는 달달한 것을 좋아해. 사탕을 원해.
# ----------------------------------------
# File: train_827
# Sentence: #Person1#: 조기 취소에 대한 0.2%의 수수료를 내셔야 한다는 것을 알고 계셨나요?
# ----------------------------------------
# File: train_827
# Sentence: #Person1#: 유감스럽게도 그렇습니다. 이 국채는 3년 만기인데, 1년 이상 2년 미만으로 발행된 것입니다. 그래서 수수료를 내셔야 합니다. 죄송합니다.
# ----------------------------------------
# File: train_829
# Sentence: #Person1#: 오, 안녕하세요! 저는 바바라 존슨이에요. 만나서 반갑습니다.
# ----------------------------------------
# File: train_829
# Sentence: #Person1#: 바바라요. 하지만 제발, 그냥 바브라고 불러주세요.
# ----------------------------------------
# File: train_830
# Sentence: #Person1#: 맞아요, 면접 보러 갔을 때 대부분의 직원들이 캐주얼하게 입고 있더라고요. 매니저만이 정장에 넥타이를 매고 있었고, 방금 행사에서 막 돌아온 것 같았어요. 복장 규정이 그렇게 딱딱하지 않은 것 같아요. 자동차 열쇠와 간단한 셔츠를 입어야겠어요.
# ----------------------------------------
# File: train_854
# Sentence: #Person1#: 시각적으로 정말 흥미진진한 영화라고 생각했어요.
# ----------------------------------------
# File: train_855
# Sentence: #Person2#: 뉴욕은 물가가 꽤 비싼 도시예요. 그래서 우리 각자가 하루에 200달러를 받게 될 거예요.
# ----------------------------------------
# File: train_864
# Sentence: #Person1#: 잘했어. 안 된다고 말해서 다행이야. 마리아는 스스로 해야 해.
# ----------------------------------------
# File: train_864
# Sentence: #Person2#: 마리아는 똑똑하지만, 나는 그냥 게으르다고 생각해.
# ----------------------------------------
# File: train_866
# Sentence: #Person1#: 아, 버스가 빨리 왔으면 좋겠어요! 발이 꽁꽁 얼어붙었어요. 여기 온 지 10분 정도 된 것 같아요.
# ----------------------------------------
# File: train_866
# Sentence: #Person1#: 오늘 아침에는 햇볕이 쨍쨍했어요!
# ----------------------------------------
# File: train_890
# Sentence: #Person2#: 그리고 정크푸드에는 지방과 기름이 많이 들어있죠. 많은 사람들이 뚱뚱한 마지막 이유가 하나 더 있어요.
# ----------------------------------------
# File: train_890
# Sentence: #Person1#: 와우! 사람들이 그렇게 뚱뚱한 것도 당연하죠. 칼, 운동을 좀 더 해야 할 것 같은데요.
# ----------------------------------------
# File: train_893
# Sentence: #Person1#: 이전 상사가 강등당한 후 그 자리를 대체하는 것이 좀 이상하게 느껴지지 않아요?
# ----------------------------------------
# File: train_901
# Sentence: #Person1#: (고통 속에서 울며) 아아아!
# ----------------------------------------
# File: train_904
# Sentence: #Person2#: 아니, 몇 주 후에 작은 식물들을 흙 속에 넣을 거야. 그런 다음 흙이 너무 건조해지지 않도록 물을 줄 거야. 그 후 몇 주 후에 밭에 줄을 지어 심을 거야.
# ----------------------------------------
# File: train_909
# Sentence: #Person2#: 저는 밤늦게까지 일해야 하는 경우가 많아요. 잠을 깨워줄 무언가가 필요해요.
# ----------------------------------------
# File: train_919
# Sentence: #Person1#: 이 책을 읽어보세요. 아주 흥미진진해요.
# ----------------------------------------
# File: train_920
# Sentence: #Person2#: 이민자 소녀가 미국에서 꿈을 이루는 과정을 그린 드라마에요. 시트콤이지만 정말 똑똑하고 정말 재밌어요. 당신도 좋아할 것 같아요.
# ----------------------------------------
# File: train_922
# Sentence: #Person1#: 기다려봐! 켜지지가 않네...
# ----------------------------------------
# File: train_933
# Sentence: #Person1#: 바다는 잔잔하고 평화로워요. 요즘처럼 날씨가 좋을 때 바다 여행은 언제나 즐겁거든요.
# ----------------------------------------
# File: train_944
# Sentence: #Person2#: 걱정 마세요. 보험 회사에 맡기기만 하세요.
# ----------------------------------------
# File: train_945
# Sentence: #Person2#: 일의 종류에 따라 다릅니다. 보통 혼자 일하는 것을 선호합니다. 왜냐하면 저는 스스로를 자극할 수 있기 때문입니다. 하지만 필요하다면 팀에 참여하는 것을 주저하지 않습니다.
# ----------------------------------------
# File: train_956
# Sentence: #Person2#: 상사의 아내가 일본인인데요. 정말 맛있는 초밥을 만든다고 하더라고요.
# ----------------------------------------
# File: train_958
# Sentence: #Person1#: 상상이 가.
# ----------------------------------------
# File: train_972
# Sentence: #Person2#: 그럼, 금요일에 스스로 뭔가 먹을 것을 살 수 있겠네요.
# ----------------------------------------
# File: train_973
# Sentence: #Person2#: 여씨, 이 문제로 당신을 도와드릴 수 없어요. 저는 약사이지, 의사가 아니에요. 그리고 지금 다른 고객을 도와야 해요. 이런 일이 발생할 때 매우 답답하다는 것을 알아요. 하지만 제가 할 수 있는 것은 없어요. 죄송해요.
# ----------------------------------------
# File: train_979
# Sentence: #Person2#: 오, 안녕하세요 루카스님, 들어오세요. 저는 바바라입니다. 만나서 반갑습니다.
# ----------------------------------------
# File: train_997
# Sentence: #Person1#: 스트레스는 현실적인 문제예요. 상상의 상태가 아니에요.
# ----------------------------------------
# File: train_997
# Sentence: #Person1#: 당신은 약하지 않아요. 스트레스를 많이 받는 거죠! 스트레스는 수백만 년 동안 인간 조건의 일부였습니다. 우리가 아직 나무에 살던 시절에는 포식자를 조심해야 했어요. 여러분이 상상할 수 있듯이 그것은 꽤 스트레스가 많았죠.
# ----------------------------------------
# File: train_997
# Sentence: #Person1#: 하지만 사실 나무에 살던 조상들과 같은 반응을 보이고 있잖아요! 이를 도피 또는 투쟁 반응이라고 합니다. 무언가가 우리를 위협한다고 느낄 때마다 우리 몸은 도망갈지 싸울지 결정합니다. 그리고 우리 몸에서 온갖 종류의 화학 반응을 일으킵니다.
# ----------------------------------------
# File: train_997
# Sentence: #Person2#: 마감일이 다가오면 같은 반응이 일어나나요?
# ----------------------------------------
# File: train_998
# Sentence: #Person2#: 하하하, 너 피곤하다고 했잖아.
# ----------------------------------------
# File: train_1003
# Sentence: #Person2#: 그럼 너 스스로 그것을 시도해봐.
# ----------------------------------------
# File: train_1019
# Sentence: #Person1#: 주주총회는 얼마나 자주 열리나요?
# ----------------------------------------
# File: train_1019
# Sentence: #Person2#: 주주총회는 일년에 두 번 열립니다. 보통 봄과 가을에 일정이 잡혀 있어요. 총회 사이에 각 주주에게는 반기 보고서가 전달됩니다. 재정 보고서는 일년에 한 번 발표됩니다.
# ----------------------------------------
# File: train_1019
# Sentence: #Person1#: 실제로 총회에 참석하는 주주들은 어느 정도의 비율일까요? 큰 비율은 아닐 것 같아요...
# ----------------------------------------
# File: train_1019
# Sentence: #Person2#: 맞아요, 참석하는 주주의 비율은 낮습니다. 또한, 총회에 참석하려면 일정량의 주식을 보유하고 있어야 합니다. 그 수량이 꽤 많아서 대부분의 주주들은 참석에서 제외됩니다.
# ----------------------------------------
# File: train_1019
# Sentence: #Person1#: 그렇다면 주주들은 실제로 얼마나 많은 의사를 표현할 수 있나요?
# ----------------------------------------
# File: train_1047
# Sentence: #Person2#: 이번에는 양양 핫팟을 시도해 보죠. 맵지 않은 국물을 선택하실 수 있어요.
# ----------------------------------------
# File: train_1061
# Sentence: #Person2#: 그럼 센트럴 파크가 여유를 즐기기에 아주 좋은 장소입니다. 다양한 식물들도 많아요. 그리고 그 주변에 쇼핑몰도 있답니다.
# ----------------------------------------
# File: train_1075
# Sentence: #Person1#: 사과, 오렌지, 바나나 중에 어떤 과일을 가장 좋아하시나요?
# ----------------------------------------
# File: train_1075
# Sentence: #Person2#: 바나나에요.
# ----------------------------------------
# File: train_1076
# Sentence: #Person2#: 아니요, 보통 서서 가요.
# ----------------------------------------
# File: train_1077
# Sentence: #Person2#: 네, 그의 얼굴은 정말 남성적이에요, 곧은 코와 무한한 눈을 가지고 있죠. 서양에서 중간 키의 남자로, 그는 강력하면서도 우아한 몸매를 유지하고 있어요, 말라 보이지도 않고 뚱뚱해 보이지도 않아요.
# ----------------------------------------
# File: train_1106
# Sentence: #Person2#: 제 것은 별로 안 좋았어요. 소소한 이야기를 나누는 건 저한테 안 맞아서요, 하지만 오랜만에 친구들을 만나니 좋았어요.
# ----------------------------------------
# File: train_1109
# Sentence: #Person1#: 의사 선생님, 제가 열이 나나요?
# ----------------------------------------
# File: train_1111
# Sentence: #Person2#: 아니, 의도적으로 다양한 운동을 균형있게 하고 있어; 평행봉, 팔굽혀펴기, 윗몸일으키기, 토끼 점프, 5킬로미터 달리기 등등. 요일마다 번갈아가며 하고 있어. 가끔, 몸 상태가 안 좋을 때는 그냥 공원에서 빈둥거려.
# ----------------------------------------
# File: train_1111
# Sentence: #Person2#: 좋은 습관을 유지하는 건 쉽지 않아. 한 번 일찍 일어나는 것을 실패하면 다음날 더 일찍 일어나기 힘들어질까봐 두려워. 게다가, 아침 일찍 산책하는 것도 꽤 재미있어. 공원 곳곳에서는 오페라나 오래된 노래를 부르거나, 이르후를 연주하거나, 체스를 두거나, 그냥 수다를 떠는 노인들의 모임을 만날 수 있어. 그들과 함께하는 것이 흥미롭거든.
# ----------------------------------------
# File: train_1123
# Sentence: #Person1#: 마지막 회의에서 주주들이 우리 회사와 블라이코어의 합병을 막기 위해 일제히 투표했습니다. 모든 경영진은 합병을 찬성했는데... 주주들이 어떻게 이런 힘을 가질 수 있었는지 이해가 안 돼요.
# ----------------------------------------
# File: train_1123
# Sentence: #Person2#: 그들이 특정 문제에서 모두 하나로 뭉치면, 최종 결정은 주주들이 하는 거예요. 최고 경영자나 직원들이 그럴 것 같지만, 실제로는 주주들이 돈을 통제하니 그들이 가장 큰 권력을 가지죠.
# ----------------------------------------
# File: train_1123
# Sentence: #Person2#: 가장 효율적이지는 않을 수 있지만, 생각해보면 꽤 합리적인 방법이에요. 주주들은 우리의 투자자죠. 우리 회사의 자본을 소유하고 있으니, 회사에서 무슨 일이 일어나는지에 대해 의견을 가지고 있어야 해요.
# ----------------------------------------
# File: train_1153
# Sentence: #Person2#: 안녕, 존. 별 거 없어. 금요일인데 심심해. 아직 계획은 없어. 뭐 생각해?
# ----------------------------------------
# File: train_1166
# Sentence: #Person2#: 숫자로 보면, 방문자의 거의 절반이 네트워크 브라우저나 검색 엔진이 아닌, 우리의 순환 삽입 링크에서 링크를 얻었어요. 그것은 소비자들이 웹 형식을 통해 우리의 제품과 서비스에 대한 정보를 목적적이고 적극적으로 찾고 있다는 것을 의미해요. 이러한 결과를 바탕으로, 인터넷이 미래의 마케팅 힘이 될 것이라고 완전히 확신해요!
# ----------------------------------------
# File: train_1184
# Sentence: #Person2#: 이전에 공장들은 목재 구조였고 무거운 기계로 인해 건물이 진동하며 화재 위험도 있었다고 읽었어요. 하지만 20세기 전환기에 칸이 자동차 공장을 디자인하기 시작했을 때, 강화 콘크리트가 막 발명된 상황이었죠. 그것만 해도 큰 혁신이었어요, 건물들이 단단하고 방화 처리가 되어 있었으며, 건설하기에도 저렴했거든요!
# ----------------------------------------
# File: train_1185
# Sentence: #Person2#: 제가 휴가를 가면 운동을 많이 하고 싶어요. 그냥 있기만 하고 아무것도 하지 않는 것은 싫어요. 사무실에서 그런 일이 충분해요. 제 말은, 제가 수영이나 워터 스키 같은 것을 즐기는 사람이라는 거죠. 물과 관련된 모든 것을 좋아하고, 삼만하게 지내는 것도 괜찮아요. 제가 스스로 돌볼 줄 알아요. 군대에 있을 때는 해가 뜨는 것을 보려고 매일 아침 다섯 시에 일어났어요.
# ----------------------------------------
# File: train_1185
# Sentence: #Person2#: 대학 때 많이 노를 저었었지만, 요즘은 좀 연습이 부족해요. 템스강에서 보트를 타고 다녔던 지도 벌써 10년이나 됐네요. 아니요, 휴가 동안 노를 저어 보내고 싶지는 않아요.
# ----------------------------------------
# File: train_1188
# Sentence: #Person1#: 많은 걸 배우고 있어, 컨트리 음악의 역사, 노래 부르는 법, 기타 치는 법 등등.
# ----------------------------------------
# File: train_1191
# Sentence: #Person2#: 봐, 텔레비전을 보면서도 많은 것을 배울 수 있어. 단지 똑똑하게 보면 돼. 정보를 필터링하고, 듣는 것을 믿을지 말지 결정해야 해.
# ----------------------------------------
# File: train_1201
# Sentence: #Person2#: 오, 모르겠네, 항상 수수료가 많아.
# ----------------------------------------
# File: train_1201
# Sentence: #Person1#: 음, 취소 수수료는 200 달러이지만...
# ----------------------------------------
# File: train_1203
# Sentence: #Person1#: 쇼핑을 하고 싶은데 런던은 물가가 비싸다고 들었어요.
# ----------------------------------------
# File: train_1233
# Sentence: #Person2#: 이럴 수가! 왜 이런 일들이 저에게만 일어나나요! 더 이상 견딜 수 없어요! 차에서 내려주세요!
# ----------------------------------------
# File: train_1288
# Sentence: #Person1#: 언제 처음 미술을 시작하셨나요? 그리고 예술가가 된 인생의 전환점은 무엇인가요?
# ----------------------------------------
# File: train_1288
# Sentence: #Person2#: 어릴 때부터 그림 그리는 것을 좋아했기 때문에 그때부터 예술가가 되겠다는 생각을 했어요.
# ----------------------------------------
# File: train_1289
# Sentence: #Person2#: 정말 죄송하지만 그건 제 문제가 아니에요. [오, 스미스 선생님!] 그건 제가 도와드릴 수 없어요. 여기서 책임을 전가하지 마세요. [스미스 부인!] 스스로를 코너에 몰아넣으셨어요. 책임을 회피하려고 하지 말고 자신의 행동에 대해 책임을 져야 합니다. 수업 성적이 좋지 않으시긴 하지만, 나쁜 선택의 결과를 회피하시려는 모습에 거의 A 학점을 드려야 할 것 같아요.
# ----------------------------------------
# File: train_1289
# Sentence: #Person1#: 아아.
# ----------------------------------------
# File: train_1294
# Sentence: #Person1#: 세계보건기구에 따르면 약 16억 명의 성인이 과체중이라고 해요. 그 중 최소 4억 명은 너무 뚱뚱해요.
# ----------------------------------------
# File: train_1296
# Sentence: #Person2#: 아니요, 1988년에 퇴사했어요. 그 이후로 프리 디자이너로 일하고 있어요. 이탈리아 회사들과 미국 회사들을 위해 디자인했고, 지난 5년 동안은 영국 회사 버버리에서도 디자인을 했어요.
# ----------------------------------------
# File: train_1316
# Sentence: #Person2#: 아주 오래전이에요. 처음 여자들을 데리러 바에 갔을 때 가장 예쁜 여자가 앉아서 콜라를 마시고 있는 걸 봤어요. 그래서 제가 다가가서 '술 한 잔 사줄까요? '라고 말했어요.
# ----------------------------------------
# File: train_1324
# Sentence: #Person2#: 수수료를 내야 하는데 은행 명세서를 받지 못했어요.
# ----------------------------------------
# File: train_1324
# Sentence: #Person2#: 수수료가 올라갔는데 납부해야 할 수수료가 있는지도 몰랐어요.
# ----------------------------------------
# File: train_1324
# Sentence: #Person2#: 수수료를 내지 않아도 되나요?
# ----------------------------------------
# File: train_1324
# Sentence: #Person1#: 초기 수수료만 내시면 됩니다.
# ----------------------------------------
# File: train_1327
# Sentence: #Person2#: 괜찮아 보였어요. 운하 반대편에 있었기 때문에 멈춰서서 이야기를 나누지는 않았어요. 그냥 서로 손을 흔들었어요.
# ----------------------------------------
# File: train_1329
# Sentence: #Person2#: 하하, 재밌네요. 명심할게요, 하지만 남편한테는 말하지 마세요.
# ----------------------------------------
# File: train_1342
# Sentence: #Person1#: 너 휴가가 필요해.
# ----------------------------------------
# File: train_1342
# Sentence: #Person1#: 너 휴가가 필요해. 그게 너의 문제야.
# ----------------------------------------
# File: train_1345
# Sentence: #Person2#: 그럴 수 없어요. 저는 이 분의 연설을 들으려고 여기 온 거예요. 연설이 끝날 때 그에게 다가가서 몇 가지 질문을 해봐야겠어요.
# ----------------------------------------
# File: train_1350
# Sentence: #Person2#: 물이 빠지지 않아요.
# ----------------------------------------
# File: train_1353
# Sentence: #Person1#: 계좌를 저희 은행으로 옮기기로 결정하신 이유를 여쭤봐도 될까요?
# ----------------------------------------
# File: train_1353
# Sentence: #Person2#: 하하! 사실, 이전 은행에서 제공하던 서비스보다 다양한 서비스가 훨씬 더 좋다고 느꼈어요. 게다가 이곳에서 은행을 이용하는 친구들이 많은데 모두 매우 만족하고 있어요.
# ----------------------------------------
# File: train_1376
# Sentence: #Person1#: 그것도 맞아. 달달하다는 뜻이야. 무슨 재료가 들어갔는지 맞춰봐.
# ----------------------------------------
# File: train_1378
# Sentence: #Person1#: 사실 그 시점에서의 반죽은 매우 심심하니, 맛을 내기 위해 향료를 추가해요.
# ----------------------------------------
# File: train_1379
# Sentence: #Person2#: ... 그리고 컴퓨터가 스파이웨어와 큰 바나나 트로이 목마 바이러스에 감염된 것 같아요.... [그게 정상입니다.] 그게 제 가장 큰 ... 그게 정상이라고요? ... 그게 제 가장 큰 걱정거리예요.
# ----------------------------------------
# File: train_1393
# Sentence: #Person1#: 근데 지난번에 갔을 때는 너무 붐벼서 30분 가까이 줄을 서서 기다려야 했어요.
# ----------------------------------------
# File: train_1398
# Sentence: #Person1#: 오해해서 죄송합니다.
# ----------------------------------------
# File: train_1409
# Sentence: #Person2#: 그래, 나는 그렇지만, 하지만 주름과 피부 처짐에 지쳐서 성형수술을 할 때가 된 것 같아아. 보여?
# ----------------------------------------
# File: train_1409
# Sentence: #Person2#: 난 네가 내 친구라서 나를 지지해 줄 거라고 생각했어! 난 그냥 나 자신에 대해 더 기분이 좋아지고 더 매력적으로 느껴지고 싶을 뿐이야.
# ----------------------------------------
# File: train_1413
# Sentence: #Person2#: 지난 8년 동안 은행 업계에서 일해 왔습니다. 저는 회계 개념에 대한 탄탄한 이해와 분석적인 마인드, 그리고 세부 사항에 대한 강한 집중력을 갖추고 있습니다. 고객 서비스 교육과 경험을 많이 쌓았고, 이 분야에서 탁월하다는 말을 많이 들었습니다.
# ----------------------------------------
# File: train_1429
# Sentence: #Person2#: 제 이름은 완메이이고 광저우에 살고 있습니다. 1987년에 태어났어요. 저는 지난 대학교에 재학 중입니다. 저는 행정학을 전공했고 여행을 매우 좋아하고 스포츠를 즐깁니다. 저는 대학교 테니스 클럽에 소속되어 있습니다.
# ----------------------------------------
# File: train_1437
# Sentence: #Person1#: 지구 온난화가 곳곳에 영향을 미치고 있어요.
# ----------------------------------------
# File: train_1438
# Sentence: #Person1#: 실례합니다만, 뽁뽁이를 구매하고 소포를 부치려면 어느 줄에 서야 하는지 알려주시겠어요?
# ----------------------------------------
# File: train_1438
# Sentence: #Person2#: 뽁뽁이는 여기서 사셔도 되지만, 소포를 부치시려면 이쪽에 줄을 서셔야 합니다.
# ----------------------------------------
# File: train_1438
# Sentence: #Person1#: 그리고 뽁뽁이는요?
# ----------------------------------------
# File: train_1440
# Sentence: #Person1#: 부가가치세 별도 1박에 84유로입니다.
# ----------------------------------------
# File: train_1446
# Sentence: #Person2#: 학이 소나무와 함께 있는 이 그림은 어때요? 중국 명나라 때 유명한 화가가 그린 그림이에요.
# ----------------------------------------
# File: train_1459
# Sentence: #Person2#: 수분 유지를 위해 이뇨제인 하이드로클로로티아지드를 처방해 드릴 거예요.
# ----------------------------------------
# File: train_1459
# Sentence: #Person2#: 지금은 두 번째 약인 ACE 억제제인 리시노프릴을 복용하세요.
# ----------------------------------------
# File: train_1462
# Sentence: #Person1#: 수수료는 어떻게 되나요? 유럽 공급업체로부터 수입품에 대해 보통 3~5%의 수수료를 받습니다. 이것이 일반적인 관행입니다.
# ----------------------------------------
# File: train_1462
# Sentence: #Person2#: 저희는 원칙적으로 수수료를 받지 않습니다. 하지만 주문이 상당한 규모라면 고려할 수 있습니다.
# ----------------------------------------
# File: train_1462
# Sentence: #Person1#: 그렇지만 저는 수수료 기반으로 비즈니스를 하고 있습니다. 가격에 수수료를 붙이면 판매 촉진이 더 쉬워질 것 같아요. 2~3%라도 도움이 될 거예요.
# ----------------------------------------
# File: train_1466
# Sentence: #Person1#: 그건 스탠리가 노래하는 걸 듣기 전이었어! 아마도 더 이상 참을 수 없어서 스스로 시도해보기로 결정한 것 같아! 앨런의 목소리는 정말 좋아! 엔리케 이글레시아스처럼 들려!
# ----------------------------------------
# File: train_1473
# Sentence: #Person2#: 공공시설 회사에 연락해서 수도전기를 본인 이름으로 이전하도록 조치를 취해야 합니다.
# ----------------------------------------
# File: train_1489
# Sentence: #Person1#: 17일에 농구 동아리 모임이 있는데, 어디서 만나나요?
# ----------------------------------------
# File: train_1507
# Sentence: #Person2#: 좋아요. 거래로 하겠습니다. 그리고 배송을 앞당기기 위해 최선을 다하겠지만, 여러분의 신용장은 9월 초에 개설되어야 해요.
# ----------------------------------------
# File: train_1524
# Sentence: #Person2#: 매우 흥미진진하고 재미있었지만 첫 30분은 놓쳤어요.
# ----------------------------------------
# File: train_1526
# Sentence: #Person2#: 저는 재택근무를 하기 때문에 근무 시간을 스스로 정할 수 있어요. 보통 자정이나 새벽 1시까지 일하고 그다음에는 늦잠을 자요.
# ----------------------------------------
# File: train_1526
# Sentence: #Person1#: 저는 충분한 수면을 취하기 위해 밤 9시나 10시쯤 잠자리에 드는 것을 좋아해요. 저희는 스케줄이 매우 다르거든요! 스스로 스케줄을 정할 수 있어서 다행이지만, 저는 그렇게 늦게까지 잠을 잘 수 없어요. 저는 확실히 아침형 인간이에요.
# ----------------------------------------
# File: train_1536
# Sentence: #Person2#: 물론이죠. 그래서 이 타입을 구입했어요. 케이스를 자주 바꿀 수 있어서 사용하는 재미가 쏠쏠해요.
# ----------------------------------------
# File: train_1546
# Sentence: #Person1#: 사실 당근 먹는 것도 괜찮아. 근데 초콜릿 케이크가 더 좋다니까. 달달한 거 태어나서 좋아했어.
# ----------------------------------------
# File: train_1559
# Sentence: #Person1#: 그렇게 말씀해 주셔서 감사합니다. 그런데 단가가 어떻게 되나요?
# ----------------------------------------
# File: train_1561
# Sentence: #Person2#: 아니! 그렇게 생각하지 않아, 마리아. 나한테는 괜찮은 맛인 것 같아. 우리 이 곳에 전에도 왔었고, 스프 맛이 다르게 느껴지지 않아.
# ----------------------------------------
# File: train_1567
# Sentence: #Person2#: 그런 것 같아. 존이나 나나 언어에 재능이 없어. 독일어로 말하려고 하면 다들 웃거든. 너랑 제인은 어떻게 그렇게 빨리 쉽게 배웠어? 독일에 한 달도 안 된 거 같은데.
# ----------------------------------------
# File: train_1578
# Sentence: #Person1#: 실제로 면접장에 갔을 때 대부분의 직원들이 캐주얼한 복장을 하고 있었어요. 매니저만 정장 차림에 넥타이를 매고 있었는데 기념식을 마치고 막 돌아왔더라고요. 복장 규정이 그렇게 딱딱하지 않은 것 같아요. 아마 자동차 열쇠와 간단한 셔츠를 입어야 할 것 같아요.
# ----------------------------------------
# File: train_1583
# Sentence: #Person2#: 빌려주셔서 죄송해요. 그럼 이건 어때요? 젊은 작가가 쓴 신간 소설이에요. 줄거리가 빠르게 전개되고 문장이 읽기 쉬워요.
# ----------------------------------------
# File: train_1597
# Sentence: #Person1#: 차나 버스에서 내리는 것은 위험하기 때문이죠. 야생 동물이 얼마나 사나운지 상상만 해도 알 수 있잖아요.
# ----------------------------------------
# File: train_1598
# Sentence: #Person1#: 저는 여전히 두 사람이 화해해보는 것이 좋다고 생각해요.
# ----------------------------------------
# File: train_1604
# Sentence: #Person2#: 몰라. 아마 그들은 괜찮다고 느끼고, 빠르게 운전하는 걸 멋있다고 생각나나 봐.
# ----------------------------------------
# File: train_1608
# Sentence: #Person1#: 또한, 존슨 선생님, 소개로 인해 부동산이 성공적으로 팔린 경우 거래 가격의 1%에 해당하는 수수료를 부과할 것임을 알려드립니다.
# ----------------------------------------
# File: train_1618
# Sentence: #Person2#: 줄을 서서 한참을 기다리다가 드디어 제가 데스크에 올라갈 차례가 되었어요. 비자를 제시하라는 요청을 받았어요.
# ----------------------------------------
# File: train_1630
# Sentence: #Person1#: 저 로봇 봤어요? 정말 똑똑했어요. 기술 박람회에 얼마나 많은 종류가 있었는지 믿을 수가 없어요. 로봇도 정말 많은 일을 할 수 있었어요. 사람 손으로만 할 수 있다고 생각했던 일들도요.
# ----------------------------------------
# File: train_1631
# Sentence: #Person2#: 아니요, 디지털 카메라라고 해야 할 것 같아요. 사진을 찍는 데는 전혀 소질이 없거든요. 항상 사진의 주요 부분을 놓치는 경우가 많은데, 디지털 카메라는 원하는 사진을 얻을 때까지 몇 번이고 반복해서 찍을 수 있거든요. 디지털 카메라는 저에게 완벽합니다. 제가 원하는 사진만 골라서 찍을 수 있으니까요.
# ----------------------------------------
# File: train_1638
# Sentence: #Person2#: 하하! 나 막 시작한 거야! 지금 바로 데려가 줘!
# ----------------------------------------
# File: train_1644
# Sentence: #Person2#: 몬트리올이 더 흥미진진해요. 쇼핑도 더 좋고요. 상점들이 더 저렴하고 재미있어요.
# ----------------------------------------
# File: train_1649
# Sentence: #Person2#: 방금 독일에서 유로로 돈을 좀 송금했어요.
# ----------------------------------------
# File: train_1655
# Sentence: #Person1#: 그럼 너도 꽤 심심한 거네.
# ----------------------------------------
# File: train_1668
# Sentence: #Person2#: 그럼 왜 남자가 중국인이고 여자가 서양인인 동서양 커플은 많지 않은 거죠?
# ----------------------------------------
# File: train_1675
# Sentence: #Person2#: 그렇군요, 저는 말할 기회가 충분히 주어지지 않아서, 수업 규모가 좀 더 작았으면 좋겠어요. 하지만 선생님들은 너무 좋아요.
# ----------------------------------------
# File: train_1682
# Sentence: #Person2#: 네, 필요한 게 있으면 말씀드릴게요. 음, 매트리스가 아주 단단하네요. 잭이 좋아할 것 같아요.
# ----------------------------------------
# File: train_1682
# Sentence: #Person2#: 네, 이 매트리스 아주 좋네요. 꽤 단단해요. 지금 사용하고 있는 매트리스는 쳐졌거든요.
# ----------------------------------------
# File: train_1682
# Sentence: #Person1#: 맞습니다. 아주 좋은 브랜드입니다. 쉽게 쳐지지 않고 평생 보증을 제공하니 품질 걱정은 안 하셔도 됩니다.
# ----------------------------------------
# File: train_1684
# Sentence: #Person2#: 정말? 나는 그렇게 많은 관심을 받고 싶지는 않더라. 최근 몇 년 동안 파파라치가 스타들의 사생활을 방해하는 경우가 많았잖아.
# ----------------------------------------
# File: train_1699
# Sentence: #Person1#: 알겠습니다, 지금 바로 처리해 드릴게요. 제가 이전에 말씀드렸던 것처럼, 이 서비스를 이용하시려면 20위안의 추가 수수료가 부과됩니다.
# ----------------------------------------
# File: train_1699
# Sentence: #Person2#: 네, 그 전에 그렇게 청구하셨던 것 기억합니다. 그때는 너무 비싸다고 생각했었어요! 하하!
# ----------------------------------------
# File: train_1707
# Sentence: #Person1#: 좋습니다. 발진을 한번 살펴보죠... 생각보다 심해 보이네요. 연고를 처방해 드릴게요. 만약 발진이 며칠 안에 없어지지 않으면 다시 오세요. 다른 증상은 없으신가요?
# ----------------------------------------
# File: train_1708
# Sentence: #Person2#: 하지만 좋든 싫든 간에, 빠르게 발전하는 사회에서 뒤처지지 않으려면 평생 공부를 해야 하는 추세입니다. 그리고 이 개념을 긍정적으로 받아들이셔야 해요.
# ----------------------------------------
# File: train_1709
# Sentence: #Person1#: 이런 카펫은 단가가 얼마인지 알려주시겠어요?
# ----------------------------------------
# File: train_1720
# Sentence: #Person2#: 저는 말썽꾸러기였고, 땡땡이를 쳤습니다. 그래서 학교에서 일주일 동안 교실을 청소하라는 벌을 받았습니다.
# ----------------------------------------
# File: train_1730
# Sentence: #Person2#: 그 정도만 하면 끝나나요?
# ----------------------------------------
# File: train_1732
# Sentence: #Person2#: 아아아아, 아아아아.
# ----------------------------------------
# File: train_1735
# Sentence: #Person1#: 이 책을 추천드려요. 매우 흥미진진해요.
# ----------------------------------------
# File: train_1735
# Sentence: #Person2#: 감사합니다. 좋은 생각 같아요. 어머니가 흥미진진한 책을 좋아하시거든요. 다른 책도 추천해 주시겠어요?
# ----------------------------------------
# File: train_1744
# Sentence: #Person1#: 응. MSN, QQ, 스카이프, 구글 토크, 알리 왕왕, 모두 열어 둬. 그래야 친구들 그리고 친척들과 연락을 주고 받을 수 있잖아.
# ----------------------------------------
# File: train_1758
# Sentence: #Person2#: 여기 있습니다. 송금수수료는 어떻게 되나요?
# ----------------------------------------
# File: train_1758
# Sentence: #Person1#: 수수료는 1퍼센트로 총 10위안 되겠습니다.
# ----------------------------------------
# File: train_1769
# Sentence: #Person2#: 술은 그저 일부일 뿐이야. 내 말은, 친구들이 많이 와서 즐거운 시간을 보내잖아. 술도 마시고 이야기도 하고. 술을 많이 마실수록, 더 많은 이야기를 하게 돼. 정말 편안해지지.
# ----------------------------------------
# File: train_1769
# Sentence: #Person2#: 오래 됐지. 여자를 꼬시려고 처음 바에 갔을 때, 가장 예쁜 여자가 앉아서 콜라를 마시고 있었어. 그래서 그 여자에게 다가가서 '술 한 잔 사도 될까요?'라고 말했지..
# ----------------------------------------
# File: train_1773
# Sentence: #Person1#: 상품권이나 현금은 실용적이죠. 하지만 상상력이 부족해요.
# ----------------------------------------
# File: train_1775
# Sentence: #Person1#: 음, 큰 언니가 아기를 낳았어. 그래서 그걸 축하하는 자리야.
# ----------------------------------------
# File: train_1783
# Sentence: #Person1#: 네. 단오절은 고대 유명한 시인인 굴원을 추모하기 위한 행사입니다. 그날 사람들은 보트 경주를 개최하는데, 이는 강에 몸을 던진 굴원을 구하고자 하는 상징적 의미를 담고 있습니다.
# ----------------------------------------
# File: train_1791
# Sentence: #Person1#: 좋아. 시간표를 확인해서 다음 버스가 언제 오는지 알아봐봐.
# ----------------------------------------
# File: train_1796
# Sentence: #Person2#: 스스로 적응하려고 노력합니다.
# ----------------------------------------
# File: train_1812
# Sentence: #Person2#: 한 가지 좋은 방법은 팔굽혀펴기를 하는 것입니다. 또 다른 방법은 웨이트를 사용하는 겁니다. 웨이트를 단단히 잡으셔야 합니다. 발에 떨어뜨리지 않도록 주의하세요!
# ----------------------------------------
# File: train_1814
# Sentence: #Person2#: 하루 종일 영어를 사용하다 보면 배울 수밖에 없더라고요. 차차 알게 되실 거예요. 학원에서 몇 주 공부해도 비슷한 효과를 볼 수 있을 거예요.
# ----------------------------------------
# File: train_1817
# Sentence: #Person2#: 음, 전자기기가 재미있을 수 있어요, 하지만 비싼 장비가 많이 필요한 취미는 원치 않으시겠죠?
# ----------------------------------------
# File: train_1832
# Sentence: #Person1#: 아니, 너 틀렸어. 돈으로 행복과 건강을 살 수는 없어. 나는 돈을 얻기 위해 건강을 희생하고 싶지 않아. 다시 말해, 나는 백만장자가 되고 싶지 않고, 삶을 즐기기 위해 더 많은 자유 시간을 가지고 싶어.
# ----------------------------------------
# File: train_1835
# Sentence: #Person2#: 줄거리가 좋았어요. 정말로 흥미진진하고 변화무쌍해요. 주인공도 마음에 들고요. 여자 주인공이 정말 재미있고 똑똑해요.
# ----------------------------------------
# File: train_1848
# Sentence: #Person2#: 그래서 나는 백화점을 더 좋아해. 현지인처럼 도매시장에서 쇼핑하는 건 내가 익숙해지지 않는 몇 안 되는 일 중 하나야.
# ----------------------------------------
# File: train_1852
# Sentence: #Person2#: 수도꼭지가 고쳐지지 않으면 이 아파트를 빌리지 않을 겁니다.
# ----------------------------------------
# File: train_1858
# Sentence: #Person1#: 크리스, 벨기에에서 어떤 종류의 음식을 먹는지 알고 싶어요.
# ----------------------------------------
# File: train_1858
# Sentence: #Person2#: 음, 벨기에에서는 뉴욕에서와는 조금 다르게 생각합니다. 저희는 식사하는데 시간이 오래 걸립니다. 외식을 자주 하지는 않지만, 외식을 하게 되면 서너 시간 동안 테이블에 머무릅니다. 애피타이저로 시작해서, 수프, 메인 요리, 그리고 아이스크림으로 이어지는 식사입니다.
# ----------------------------------------
# File: train_1858
# Sentence: #Person1#: 벨기에에서는 저녁 식사하는 데 시간이 너무 많이 걸리네요!
# ----------------------------------------
# File: train_1871
# Sentence: #Person1#: 네, 패스트트랙 시스템을 사용하기 시작하면서 신청 절차가 빨라졌습니다.
# ----------------------------------------
# File: train_1878
# Sentence: #Person1#: 알겠습니다. 그러나 많은 구제금융안 지지자들은 이것이 수백만 명의 열심히 일하는 미국인들의 일자리를 구할 수 있을 것이라고 주장합니다.
# ----------------------------------------
# File: train_1878
# Sentence: #Person2#: 그럴 수도 있습니다, 저를 비롯한 그 누구도 일자리를 잃는 것을 보고 싶지 않지만, 이들 CEO들이 수백만 달러를 벌면서 어떻게 구제금융을 요청할 수 있을까요? 그리고 그들은 개인 제트기를 타고 워싱턴에 날아가는 뻔뻔함까지 가지고 있습니다! 이것은 수십만 달러가 듭니다! 그리고 그들은 돈을 요구하고 있습니다! 이것은 정말로 옳지 않습니다!
# ----------------------------------------
# File: train_1886
# Sentence: #Person2#: 아니요, 하지만 최근에 열심히 일한 덕분에 급여가 5% 안상되었어요. 제 상사가 그런 식으로 고마움을을 보여줘서 정말 좋았어요.
# ----------------------------------------
# File: train_1893
# Sentence: #Person1#: 신용카드 번호를 알려주시겠어요? 취소시 수수료가 20달러 부과된다는 점을 알려드립니다.
# ----------------------------------------
# File: train_1907
# Sentence: #Person1#: 아아아악!
# ----------------------------------------
# File: train_1907
# Sentence: #Person2#: 아직 만지지도 않았는데, 왜 그렇게 소리를 지르세요?
# ----------------------------------------
# File: train_1907
# Sentence: #Person2#: 당연하죠. 어떻게 만지지 않고 주사를 놓을 수 있겠어요? 주사를 맞자마자 잇몸이 마비돼서 아무것도 느끼지 못하실 거예요.
# ----------------------------------------
# File: train_1911
# Sentence: #Person2#: 단단한 상태로 사서 며칠 동안 기다리시면 말랑해집니다.
# ----------------------------------------
# File: train_1912
# Sentence: #Person2#: 맞아요. 올해는 예년보다 훨씬 더 흥미진진할 것 같아요. 가장 좋아하는 시상식 부문은 무엇인가요?
# ----------------------------------------
# File: train_1915
# Sentence: #Person2#: 네, 적어도 다들 다이어트에 대해 이야기하긴 하죠. 제 이웃은 바나나 다이어트를 하고 있어요. 아침에 바나나 한 개, 점심에 한 개, 저녁에 두 개를 먹어야 해요.
# ----------------------------------------
# File: train_1954
# Sentence: #Person2#: 가슴이 답답한 증상을 겪고 있습니다. 이에 대한 검사를 해주실 수 있나요?
# ----------------------------------------
# File: train_1968
# Sentence: #Person2#: 모든 신입사원분들이 동일한 질문을 하실 것 같네요. 하하. 이해할 수 있습니다. 매달 주말과 지정된 공휴일을 제외하고 3일의 휴가가 주어집니다. 1년을 근무하시면, 1주일의 휴가를 받으실 수 있습니다. 반차는 한 시간 전에 그리고 월차는 3일 전에 신청하셔야 합니다.
# ----------------------------------------
# File: train_1974
# Sentence: #Person1#: 좋은 생각이에요. 키를 시동 장치에 꽂고, 시동을 걸고, 후진 기어를 넣고, 도로가 비어질 때까지 기다렸다가 진입로로 차를 후진하세요.
# ----------------------------------------
# File: train_1987
# Sentence: #Person2#: 오... 음... 그건 좀 어려울 것 같아요. 할로겐 조명이 트랙 조명 시스템보다 훨씬 비싸다는 걸 알고 계시죠. 게다가 설치하려면 사람들을 불러야 합니다. 비용이 만만치 않을 거예요.
# ----------------------------------------
# File: train_1990
# Sentence: #Person1#: 그곳은 큰 의료 기기들을 보관하는 창고입니다. 급하게 주문이 들어올 경우 재고를 확보해 빠르게 처리할 수 있도록 빠르게 팔리는 품목들을 보관하고 있습니다. (작업장에서) 이곳은 세 개의 작업장 중 하나입니다. 여기가 배송 구역입니다.
# ----------------------------------------
# File: train_1993
# Sentence: #Person1#: 안녕, 테드, 나 이 신문 광고 봤는데, 너도 한번 봐봐.
# ----------------------------------------
# File: train_2002
# Sentence: #Person2#: 이 시기에는 날씨가 자주 바뀌어요. 오후 늦게는 선선해질 수 있어요.
# ----------------------------------------
# File: train_2004
# Sentence: #Person1#: 오래된 에릭슨을 쓰고 있어. 여기, 한번 봐봐.
# ----------------------------------------
# File: train_2011
# Sentence: #Person2#: 아, 로스앤젤레스는 따뜻하고 좋았고, 샌프란시스코는 쌀쌀했지만 편안했어.
# ----------------------------------------
# File: train_2011
# Sentence: #Person1#: 샌프란시스코가 쌀쌀했다고? 놀랍지 않아?
# ----------------------------------------
# File: train_2023
# Sentence: #Person1#: 빈스. 우리 둘 다 바쁘니까 빙빙 돌려 말하지 않을게요. 급여를 올려줘요.
# ----------------------------------------
# File: train_2027
# Sentence: #Person2#: 예를 들어, 내가 건축학을 공부하지 않았다면, 원하던 대로 예술가가 되었을 거야.
# ----------------------------------------
# File: train_2032
# Sentence: #Person1#: 진정하세요, 엘빈. 조심하지 않으면 우리 계획이 들통날 수 있어요. 지나는 똑똑하잖아요.
# ----------------------------------------
# File: train_2042
# Sentence: #Person2#: 미안해, 마이크. 나도 무슨 일인지 모르겠어. 여기 언니가 보낸 전보야. 한번 봐봐.
# ----------------------------------------
# File: train_2046
# Sentence: #Person1#: 이쪽으로 오면 돼. 봐봐, 최신 가전제품으로 모두 갖춰져 있어, 근데...
# ----------------------------------------
# File: train_2048
# Sentence: #Person2#: 저는 환경 보호를 강력히 지지합니다. 더 많은 기차를 만들어야 한다고 생각합니다. 더 많은 사람들이 자전거를 타야 합니다. 공기를 보호해야 합니다. 모두에게 깨끗한 공기가 필요합니다. 제가 다시 상원의원으로 선출된다면, 지구를 보호하기 위해 최선을 다하겠습니다.
# ----------------------------------------
# File: train_2048
# Sentence: #Person2#: 아니요! 그렇지 않습니다. 저는 절대로 공장들이 강에 쓰레기를 버리도록 허용하는 법안에 찬성표를 던지지 않았습니다. 사실을 잘못 알고 계십니다. 저는 기업을 강력하게 지지하지만, 환경에 대한 지지는 더욱 강합니다.
# ----------------------------------------
# File: train_2050
# Sentence: #Person2#: 저는 푸딩을 잘 만들어요. 바나나 맛 푸딩을 만들어 갈게요.
# ----------------------------------------
# File: train_2064
# Sentence: #Person2#: 그럼, 주말에 초대해서 뒤늦게라도 이 흥미로운 만우절을 축하하면 되겠네요.
# ----------------------------------------
# File: train_2069
# Sentence: #Person1#: 네, 먹어봤어요. 하지만 식당에서 먹은 생선찜 맛은 별로였어요. 생선이 제대로 익혀지지 않았고 너무 짰어요.
# ----------------------------------------
# File: train_2072
# Sentence: #Person2#: 생일을 축하하며, 앞으로의 행복, 건강, 그리고 지속적인 성공을 기원합니다. 페어리 플라워에서 꽃다발을 보내달라고 부탁했어요. 마음에 드시면 좋겠어요.
# ----------------------------------------
# File: train_2075
# Sentence: #Person2#: 여름이니까 햇볕을 많이 쬐신 것 같아서 여름 스페셜을 추천해 드리겠습니다. 특히 민감한 피부를 가진 분들에게 적합합니다.
# ----------------------------------------
# File: train_2075
# Sentence: #Person2#: 얼굴 마사지는 꼼꼼한 클렌징으로 시작합니다.
# ----------------------------------------
# File: train_2080
# Sentence: #Person2#: 차를 운영하는 데 드는 비용이 생각보다 많아요, 특히 문제가 많을 때는 더더욱요!
# ----------------------------------------
# File: train_2088
# Sentence: #Person2#: 그들의 친구들을 알고 있다면요. 친구들에게만 의지해서 항상 사람들을 소개받을 수는 없습니다. 가끔은 직접 나서서 첫 단추를 끼워야 합니다. 저는 웃긴 사람들도 좋아합니다.
# ----------------------------------------
# File: train_2091
# Sentence: #Person1#: 전혀 그럴 필요 없어. 우리가 카펫을 직접 제거할 수 있어. 카펫은 카펫 못으로 고정되어 있어. 세게 당기기만 하면 위로 올라올 거야.
# ----------------------------------------
# File: train_2098
# Sentence: #Person1#: 아, 그렇군요. 상상이 가네요. 힘든 일이라고 생각해야겠죠?
# ----------------------------------------
# File: train_2105
# Sentence: #Person2#: 특별히 그렇지는 않아. 나는 통통한 여자를 좋아해.
# ----------------------------------------
# File: train_2111
# Sentence: #Person2#: 네, 그렇습니다. 읽고 들을 수 있는 것은 충분히 많습니다. 하지만 말하기에 대해서는 편안한 분위기에서 언어를 사용하고 말해보려고 노력하는 것을 대체할 수 있는 방법이 없습니다. 그래서 모국어가 통용되지 않는 나라에 사는 사람들에게는 정말 어려운 일이라고 생각합니다. 세상에, 그런 상황에서 제가 어떻게 하겠어요. 만약 여기 사람들이 없었다면, 아마 스웨덴의 클럽을 찾았을 겁니다. 스웨덴에는 '스터디 서클'이라는 정말 멋진 시스템이 있는데, 마치 강좌처럼 보이지만 실제로는 강좌 리더가 있어서 코칭 가이드로서 도와주고 성적을 따지지 않아서 그냥 배우고 싶으면 가는 곳입니다.
# ----------------------------------------
# File: train_2116
# Sentence: #Person1#: 아시다시피, 제가 최근에 미국에서 그랜저스 고메 봉봉의 독점 유통업자가 되었습니다. 이 회사는 새로운 제조업체로써 고급 시장에 진출하려고 하고 있습니다. 당연히, 귀하의 레스토랑이 바로 제 머릿속에 떠올랐어요. 저는 귀하의 브랜드가 그랜저스와 많은 공통점을 가지고 있다고 생각하고, 이 초콜릿을 제공한다면 우아하고, 고급스럽고, 최고급 식사를 제공하는 귀하의 브랜드 명성에 더욱 도움이 될 것이라고 생각합니다.
# ----------------------------------------
# File: train_2116
# Sentence: #Person1#: 그랜저 가족에게 대대로 전해 내려온 이 전통적인 비법은 최고의 신뢰를 받고 있습니다. 비밀을 지켜주실 거라 믿습니다. 버터밀크, 카카오 콩, 설탕 그리고 해기스가 들어갑니다.
# ----------------------------------------
# File: train_2120
# Sentence: #Person1#: 똑똑하네! 그러면 모두가 커플이 정말 원하는 물건을 사줄 수 있고, 선물이 겹치는 일도 없겠네. 노트에는 어떤 물건들이 있었어?
# ----------------------------------------
# File: train_2124
# Sentence: #Person1#: 계산대 뒤에 서서 피자 주문을 받았어요.
# ----------------------------------------
# File: train_2125
# Sentence: #Person1#: 해커들은 똑똑하고 그들이 똑똑하다는 것을 사람들에게 알리고 싶어해.
# ----------------------------------------
# File: train_2125
# Sentence: #Person2#: 그래서 자신들이 똑똑하다는 것을 사람들에게 알리기 위해 바이러스를 만든다는 거야? 정말 역겨운 행동이네.
# ----------------------------------------
# File: train_2130
# Sentence: #Person2#: 저는 그들이 끔찍한 삶을 살고 있을 거라고 생각해요. 모든 파파라치들이 어디를 가든, 무엇을 하든 사진을 찍어대니까요. 지긋지긋할 거예요.
# ----------------------------------------
# File: train_2131
# Sentence: #Person2#: 한 가지 좋은 방법은 팔굽혀펴기를 하는 것입니다. 또 다른 방법은 웨이트를 사용하는 겁니다. 웨이트를 단단히 잡으셔야 합니다. 발에 떨어뜨리지 않도록 주의하세요!
# ----------------------------------------
# File: train_2133
# Sentence: #Person1#: 실례합니다, 부인. 이 소포를 항공 우편으로 런던까지 집집마다 보내고 싶습니다. 매우 중요한 소포로 3일 내로 보내야 합니다.
# ----------------------------------------
# File: train_2134
# Sentence: #Person2#: 귀사는 보통 수출에 대해 얼마의 수수료를 지불하나요? 아시다시피 저희는 수수료 기반으로 수입합니다.
# ----------------------------------------
# File: train_2140
# Sentence: #Person2#: 감사합니다, 릭. 오늘 우리 앞에는 매우 흥미진진한 경기가 펼쳐질 예정입니다. 두 강팀인 브라질과 중국이 서로 대결하며 다음 라운드 진출을 노립니다. 의심할 여지 없이 두 팀 모두 최상의 컨디션을 유지하고 있어 치열한 경기가 예상됩니다.
# ----------------------------------------
# File: train_2144
# Sentence: #Person1#: 너 휴가가 필요한 거 같다.
# ----------------------------------------
# File: train_2144
# Sentence: #Person2#: 우리 증조할아버지들은 더 재미있게 살았다는 거야. 음식을 위해 사냥하고, 채소도 직접 재배하고 그리고 스스로 뭔가를 했어. 우리는 수년 동안 같은 종류의 일을 하고 있어. 우리의 삶에는 다양성이 없어.
# ----------------------------------------
# File: train_2144
# Sentence: #Person1#: 너 휴가가 필요해. 그게 바로 너의 문제야.
# ----------------------------------------
# File: train_2153
# Sentence: #Person1#: 당신이 살고 있는 도시에서는 범죄가 많이 일어나나요?
# ----------------------------------------
# File: train_2157
# Sentence: #Person1#: 스티븐은 매우 특별한 아이이고, 아이들과 잘 놀지 않는다고 했어요. 그에 대해 어떻게 생각하세요?
# ----------------------------------------
# File: train_2160
# Sentence: #Person1#: 아빠, 평일에는 항상 일정을 너무 빡빡하게 잡으시잖아요. 주말에는 쉬셔야 해요.
# ----------------------------------------
# File: train_2184
# Sentence: #Person2#: 상당히 큰 금액이네요. 하지만 전혀 문제가 없을 겁니다. 하지만 10%의 서비스 수수료가 있다는 것을 아셔야 합니다.
# ----------------------------------------
# File: train_2184
# Sentence: #Person2#: 회원님들에게는 작은 거래 수수료가 있지만, 거래당 5달러밖에 되지 않습니다. 특정 지폐가 필요하신가요?
# ----------------------------------------
# File: train_2187
# Sentence: #Person2#: 멋진 추억이 있는 건 사실이에요. 올림픽은 정말 흥미진진했어요. 하지만 몇 가지 중요한 것들을 놓치기도 했죠. 다른 여자아이들이 놀고 있을 때, 저는 수영하고 있었어요.
# ----------------------------------------
# File: train_2190
# Sentence: #Person2#: 네, 그렇습니다. 오래된 나무에 봄꽃이 피고, 사람들은 꽃을 보러 마을을 찾습니다.
# ----------------------------------------
# File: train_2193
# Sentence: #Person2#: 오늘 저녁에 저를 기다리지 말라고 전해주실 수 있나요? 함께 파티에 가기로 했는데, 중요한 일이 생겨서 급히 떠나게 됐습니다. 다음 주 초에 카이로로 돌아올 예정입니다.
# ----------------------------------------
# File: train_2198
# Sentence: #Person2#: 정말? 나는 그렇게 많은 관심을 받고 싶지는 않더라. 최근 몇 년 동안 파파라치가 스타들의 사생활을 방해하는 경우가 많았잖아.
# ----------------------------------------
# File: train_2203
# Sentence: #Person1#: 소지품을 모두 들고 다니니까 자전거를 잘 관리해야겠네요.
# ----------------------------------------
# File: train_2208
# Sentence: #Person2#: 정말 좋은 차에요. 매우 편안하고 속도도 엄청 빨라요.
# ----------------------------------------
# File: train_2220
# Sentence: #Person2#: 농담하는 거야? 7억 명이 넘는 사람들이 월드컵 결승 경기를 봤어! 정말로 흥미진진하고 긴장감 넘치는 스포츠야! 각 국가는 자국의 팀이 다음 챔피언이 되기를 바라며 자신의 팀을 응원하고 있어. 지금까지 브라질이 가장 많이 우승을 차지한 팀이야. 그들은 정말로 잘해!
# ----------------------------------------
# File: train_2228
# Sentence: #Person1#: 그럴실 거예요. 어머니가 꽃을 정말 좋아하시거든요. 그래서 매년 꽃을 사드리고 있는데, 꽃들이 좀 더 오래 싱싱하게 유지되면 좋겠어요.
# ----------------------------------------
# File: train_2228
# Sentence: #Person2#: 물에 설탕과 비타민 C를 조금 넣어보세요. 며칠 동안 싱싱함을 유지할 수 있어요.
# ----------------------------------------
# File: train_2229
# Sentence: #Person2#: 엘리베이터는 매우 빠르고 움직임이 거의 느껴지지 않아요.
# ----------------------------------------
# File: train_2233
# Sentence: #Person1#: 음 ... 아, 취소 수수료가 200달러이긴 하지만 ...
# ----------------------------------------
# File: train_2235
# Sentence: #Person2#: 좋은 생각이네요. 저도 같은 방식으로 해봐야겠어요. 마음에 드는 음악을 찾을 수 있을 거예요. 클래식 음악은 사람들을 똑똑하게 만들 수 있지만, 댄스 음악은 사람들을 더 활기차고 행복하게 만들 수 있습니다.
# ----------------------------------------
# File: train_2245
# Sentence: #Person1#: 오, 존, 경치도 좋아. 이 창문에서 바다를 봐봐. 너무 편안해져.
# ----------------------------------------
# File: train_2250
# Sentence: #Person1#: 안녕하세요, 바바라. 돌아온 걸 환영해요. 좋아 보이시네요.
# ----------------------------------------
# File: train_2250
# Sentence: #Person1#: 바바라, 그 안에 뭐가 들어있나요? 책인가요, 돌인가요?
# ----------------------------------------
# File: train_2270
# Sentence: #Person2#: 이제 진실에 다가가고 있네요.
# ----------------------------------------
# File: train_2271
# Sentence: #Person2#: 그리고 그들은 신선하게 만든 톡 쏘는 살사 소스도 있어. 벌써 입안이 축축해지네!
# ----------------------------------------
# File: train_2276
# Sentence: #Person1#: 정말 잘하셨네요. 전문가가 한 것만큼이나 좋아요. 저의 화장실도 재단장해주실 수 있을까요?
# ----------------------------------------
# File: train_2280
# Sentence: #Person2#: 좋아. 지금 정말 심심하니까.
# ----------------------------------------
# File: train_2280
# Sentence: #Person2#: 알겠어. 그녀는 키가 그리 크지 않고 꽤 통통해. 금발인데, 눈 색깔은 잘 모르겠어.
# ----------------------------------------
# File: train_2280
# ...
# ----------------------------------------
# File: train_11723
# Sentence: #Person1#: 스스로 알아내. 들어봐. 나 가야 돼. 더 이야기하고 싶으면 엄마 집에서 만나.
# ----------------------------------------
# File: train_11726
# Sentence: #Person1#: 괜찮아! 하하.
# ----------------------------------------
# File: train_11726
# Sentence: #Person1#: 뭐하는 거야? 그만둬! 큰 사슴이 보여. 아, 그건 내 거야! 봐봐!
# ----------------------------------------
# File: train_11731
# Sentence: #Person2#: 적어도 회사에서 먹는 도시락보다는 낫네요. 밋밋한 음식에 질렸거든요. 같이 점심 먹어줘서 고마워요!
# ----------------------------------------
# File: train_11732
# Sentence: #Person2#: 좋은 생각이에요. 하지만 우박 때문에 차가 찌그러지지 않도록 차를 옮겨야 할 것 같아요.
# ----------------------------------------
# File: train_11732
# Sentence: #Person1#: 알았어요. 난방을 켜면 차를 옮기러 갈게요. 여기 좀 쌀쌀하네요.
# ----------------------------------------
# File: train_11768
# Sentence: #Person1#: 이번 흥미진진한 에피소드는 여기서 끝입니다. 배에 무슨 일이 일어났을까요? 외계인들은 누구일까요? 배는 잃어버린 승무원들을 찾을 수 있을까요? 다음 주 이 흥미진진한 이야기의 결말을 확인하세요.
# ----------------------------------------
# File: train_11778
# Sentence: #Person2#: 혹시 스스로 공항까지 운전해서 왔나요?
# ----------------------------------------
# File: train_11779
# Sentence: #Person2#: 아니요, 하지만 곧 호주와 뉴질랜드를 방문할 계획입니다. 아름다운 나라라고 들었어요. 가장 아름다운 나라는 어디인가요?
# ----------------------------------------
# File: train_11779
# Sentence: #Person1#: 노르웨이 북부는 거의 항상 추운데, 남부로 내려가면 여름에는 꽤 따뜻할 수 있습니다. 습한 나라라서 겨울에는 거의 어디나 눈이 내립니다.
# ----------------------------------------
# File: train_11783
# Sentence: #Person1#: 이번 주말에 흥미진진한 활동을 해보는 건 어떨까요? 마을 바깥에 박물관이 있어요.
# ----------------------------------------
# File: train_11788
# Sentence: #Person2#: 나도 마찬가지야. 하지만 내 아내의 가족은 충분히 부유해서 모두가 넉넉한 공간을 가질 수 있게 해줘. 그들은 농장을 빌렸어. 그리고 Martha와 나는 우리만의 별장이 있었어. 그래서 낮에는 아이들과 놀았지만, 필요할 때는 쉽게 사생활을 즐길 수 있었어. 그게 가족 여행에서 매우 필요한 거야.
# ----------------------------------------
# File: train_11801
# Sentence: #Person2#: 크리스마스 휴가가 끝난 후에 주문을 진행할 수 있습니다. 우리 공장은 다음 주까지 휴무입니다.
# ----------------------------------------
# File: train_11809
# Sentence: #Person2#: 음, 사실 그녀는 나보다 키가 커. 검은 머리에 꽤 탄탄한 체형이야. 음. 그녀는 너무 마르지도 않고 너무 살찐 것도 아니야.
# ----------------------------------------
# File: train_11809
# Sentence: #Person2#: 음, 그녀는 재봉틀 수업을 들었었어, 그래서 그녀는 자신의 커튼 같은 것들을 직접 만드는 것을 정말 좋아해. 심지어 몇 번은 나에게 옷도 만들어 줬어.
# ----------------------------------------
# File: train_11831
# Sentence: #Person2#: 네, 원하는 만큼 아이를 낳을 수 있습니다. 하지만 대부분의 사람들은 한 두 명만을 가지기로 결정합니다. 그리고 일부 사람들은 아예 아이를 가지지 않기로 결정하기도 합니다.
# ----------------------------------------
# File: train_11831
# Sentence: #Person1#: 왜 아이를 가지지 않기로 결정하나요? 옛날에는 우리 중국인들이 가능한 한 많이 가지려고 했습니다. 지금도 그런 사람들이 있습니다.
# ----------------------------------------
# File: train_11834
# Sentence: #Person1#: 그렇게 많이? 언제부터 물 전문가가 됐어?
# ----------------------------------------
# File: train_11835
# Sentence: #Person2#: 헤이, 만약 당신이 유명한 음악가가 된다면, 저는 당신을 인터뷰할 수 있겠네요.
# ----------------------------------------
# File: train_11851
# Sentence: #Person1#: 잠깐만요, 당신들 둘. 당신이 진실을 말하고 있지 않은 것 같아요. 이곳은 빈민가가 아니죠?
# ----------------------------------------
# File: train_11852
# Sentence: #Person1#: 노숙 청소년들은 쉽게 마약과 성매매에 연루될 수 있습니다. 그들을 돕기 위해 무엇인가를 하시나요?
# ----------------------------------------
# File: train_11852
# Sentence: #Person1#: 무언가가 바뀌어야 합니다---그리고 그것은 곧 일어나야 합니다.
# ----------------------------------------
# File: train_11861
# Sentence: #Person1#: 수수료는 어떻게 되나요? 유럽 공급자로부터는 보통 수입에 대해 3~5%의 수수료를 받습니다. 일반적인 관행입니다.
# ----------------------------------------
# File: train_11861
# Sentence: #Person2#: 원칙적으로 우리는 어떤 수수료도 허용하지 않습니다. 하지만 주문이 큰 경우에는 고려할 수 있습니다.
# ----------------------------------------
# File: train_11861
# Sentence: #Person1#: 저는 수수료 기반으로 사업을 합니다. 당신들의 가격에 대한 수수료가 판매를 촉진하는 데 도움이 될 것입니다. 2~3%라도 도움이 됩니다.
# ----------------------------------------
# File: train_11862
# Sentence: #Person1#: 저 마을을 봐!
# ----------------------------------------
# File: train_11864
# Sentence: #Person1#: 자스민차를 가져가겠습니다. 포장지와 리본으로 포장해 주실 수 있나요? 친구에게 선물할 거거든요.
# ----------------------------------------
# File: train_11868
# Sentence: #Person2#: 네. 그렇게 한 후에는 카세트를 넣습니다. 테이프의 올바른 면이 당신을 향하고 있고, 당신으로부터 멀어지지 않게 확인하세요. 그런 다음 카세트 덮개를 닫아야 합니다.
# ----------------------------------------
# File: train_11873
# Sentence: #Person2#: 정말 좋은 차에요. 매우 편안하고 속도도 굉장히 빨라요.
# ----------------------------------------
# File: train_11874
# Sentence: #Person2#: 알아. 아빠는 누군가에게 도움을 청하는 것을 좋아하지 않아. 아빠는 스스로 청구서를 내고, 자신을 돌보는 것을 고집해!
# ----------------------------------------
# File: train_11874
# Sentence: #Person2#: 아빠 같은 사람들이나 당신의 할머니 같은 사람들은 스스로 살기를 결심한 것 같아.
# ----------------------------------------
# File: train_11876
# Sentence: #Person2#: 아니요, 보통 서서 가야 합니다.
# ----------------------------------------
# File: train_11878
# Sentence: #Person1#: 마이크, 이 새우 그림 좀 봐! 너무 간단한데도 불구하고 생생하게 그려져 있어!
# ----------------------------------------
# File: train_11887
# Sentence: #Person2#: 아하하! ! ! 도와주세요! 도와주세요! 배를 좀 더 가까이 대 주세요! 상어가 곧장 저한테로 다가오고 있어요!
# ----------------------------------------
# File: train_11888
# Sentence: #Person2#: 맞아요. 올해는 여느 때보다 훨씬 더 흥미진진할 것 같아요. 가장 좋아하는 상의 카테고리는 무엇인가요?
# ----------------------------------------
# File: train_11896
# Sentence: #Person2#: 몇 주 동안만이에요. 저는 이 휴가가 필요해. 당신은 괜찮을 거예요. 우리가 작업 중인 프로젝트를 알고 있고, 당신은 좋은 과학자니까요. 걱정하지 마세요. 제 돈을 다 쓰거나 모두 도박에 쓰고 나면 바로 돌아올게요.
# ----------------------------------------
# File: train_11900
# Sentence: #Person2#: 오늘 휴일은 아니에요. 우리 노동조합이 오늘 전국적인 파업을 벌이고 있어요. 우리 부서의 모든 직원들이 노동조합을 지지하며 이번 주에는 일하지 않기로 했어요.
# ----------------------------------------
# File: train_11903
# Sentence: #Person1#: 그럼 누가 범인인가요?
# ----------------------------------------
# File: train_11912
# Sentence: #Person2#: 하하. 행운을 빌어.
# ----------------------------------------
# File: train_11920
# Sentence: #Person2#: 적어도 모두가 이에 대해 이야기하고 있지요. 제 이웃은 바나나 다이어트를 하고 있어요. 그녀는 아침에 바나나 한 개, 점심에 한 개, 저녁에 두 개를 먹어요.
# ----------------------------------------
# File: train_11920
# Sentence: #Person1#: 그건 심장에 좋지 않아요! 체중 감량에 좋은 무언가가 계란에 들어있긴 하지만, 너무 많은 계란은 심장에 해로워요.
# ----------------------------------------
# File: train_11920
# Sentence: #Person1#: 그건 은행 계좌에 좋지 않지요. 체중을 줄이는 가장 좋은 방법은 덜 먹고 더 많이 운동하는 거예요. 그러니, 봐봐요, 전 테니스 코트로 가는 길이에요.
# ----------------------------------------
# File: train_11948
# Sentence: #Person2#: 음, 운동이 어떻게 도움이 되는지 모르겠어. 마지막에 헬스장에 갔을 때, 나처럼 뚱뚱한 사람들만 보였어.
# ----------------------------------------
# File: train_11952
# Sentence: #Person1#: 하하! 많은 현지인들이 당신과 정반대로 생각할 걸요. 다들 급여를 달러로 받고 싶어하거든요.
# ----------------------------------------
# File: train_11954
# Sentence: #Person1#: 강제 침입이 분명하군요. 자물쇠가 산산조각이 났어요.
# ----------------------------------------
# File: train_11957
# Sentence: #Person2#: 네, 수수료는 제 계좌에서 차감하세요. 바로 신청서를 작성하겠습니다.
# ----------------------------------------
# File: train_11970
# Sentence: #Person2#: 수십 명의 이성이 술을 마시는 컴컴한 바에서 3분 동안 만나는 그거요? 그건 싫어요.
# ----------------------------------------
# File: train_11975
# Sentence: #Person2#: 하하, 대장 정말 똑똑하시네요!
# ----------------------------------------
# File: train_11976
# Sentence: #Person2#: 그녀가 등을 꼿꼿하게 세우고 미끄러지듯 슥 지나가는데 분위기 최고였어. 너무 뜨겁지도 차갑지도 않았어.
# ----------------------------------------
# File: train_11993
# Sentence: #Person1#: 놀라워. 해가 거의 다 졌는데도 아직 곳곳이 현란해!
# ----------------------------------------
# File: train_12003
# Sentence: #Person2#: 난창으로 1,200위안 송금 시 수수료는 12위안입니다.
# ----------------------------------------
# File: train_12024
# Sentence: #Person1#: 하와이 여행을 준비했어. 봐봐, 새로운 선글라스를 샀어.
# ----------------------------------------
# File: train_12066
# Sentence: #Person2#: 아, 저는 지난 주 대부분을 아파서 쉬었어요. 아직 완전히 나아지지 않았어요. 너무 가까이 오지 마세요!
# ----------------------------------------
# File: train_12067
# Sentence: #Person2#: 그래, 그런데 뭐 어때요! 세계에서 가장 흥미진진한 도시에 살고 있다는 것이 자랑스러워요. 게다가, 여기는 전국에서 가장 높은 급여를 받는 곳이기도 하죠.
# ----------------------------------------
# File: train_12076
# Sentence: #Person1#: 특별한 플래티넘 합금으로 만들어졌고, 그 광택은 절대 사라지지 않습니다.
# ----------------------------------------
# File: train_12077
# Sentence: #Person2#: 네, 그렇습니다. 어서 들어오세요! 오셔서 정말 다행이에요! 이 오래된 집이 무너져 내리고 있어요! 화장실로 들어오세요. 보세요, 여기 물이 곳곳에서 새고 있어요!
# ----------------------------------------
# File: train_12077
# Sentence: #Person1#: 알겠습니다. 한번 볼게요. 화장실이 막혀서 플러시가 안 되는 것 같네요. 플런저를 한번 가져와 볼게요. 아니, 이것도 안 되네요. 파이프 안에 이물질이 있어서 막힌 것 같습니다. 그게 화장실이 넘치게 만드는 원인인 것 같아요.
# ----------------------------------------
# File: train_12077
# Sentence: #Person1#: 네, 저도 아이가 있어요. 어쨌든, 이 수도관은 엄청나게 녹슬어서 교체해야 할 것 같아요. 그게 물이 완전히 빠지지 않게 만드는 원인일 수도 있어요, 그러면 미래에 더 많은 문제를 일으킬 수 있어요. 또한 제대로 꺼지지 않는 이 수도꼭지도 고치라고 권해드리고 싶네요. 급하시다면 오늘 안에 모두 끝낼 수 있어요.
# ----------------------------------------
# File: train_12096
# Sentence: #Person1#: 어제 밤에 인도인 동창인 바바라를 찾았어요. 그녀가 다리를 꼬고 조용히 연습하는 것을 발견했어요.
# ----------------------------------------
# File: train_12107
# Sentence: #Person1#: 너는 마지막에 팔이 부러지지 않았어. 이번에도 부러지지 않을 거야. 가자. 그러니까 월요일에는 호수로 가고; 화요일에는 산악 자전거를 탈 거야. [ 좋아. ] 음, 수요일에는 낚시를 가는 건 어때. 우리가 마지막으로 갔을 때 기억나? 나는 거대한 물고기를 10마리나 잡았어...
# ----------------------------------------
# File: train_12110
# Sentence: #Person1#: 그래. 나는 그들의 딸 펜을 학교에서 가르쳐. 그녀는 학교 공부에 대해 조금 무관심하고 게으르지만, 밝은 아이이고 또래 사이에서 매우 인기가 있어.
# ----------------------------------------
# File: train_12111
# Sentence: #Person2#: 이렇게 하는 게 더 좋을 것 같아요: 지금 책에 대해 반반씩 비용을 나눠서 내고, 과정이 끝날 때에는 각자 흥미로운 책을 가져가요.
# ----------------------------------------
# File: train_12120
# Sentence: #Person2#: 스스로에게 감사하셔야죠.
# ----------------------------------------
# File: train_12129
# Sentence: #Person1#: 좋습니다. 이 소나무와 학이 그려진 그림은 어떠세요? 이건 명성이 높은 중국 화가가 왕조 시대에 그린 것입니다.
# ----------------------------------------
# File: train_12133
# Sentence: #Person1#: 그렇게 생각하지 않아. 나에게는 서로 연락하는 것이 가장 멋진 컴퓨터 게임이나 가장 핫한 정보보다 더 재미있어.
# ----------------------------------------
# File: train_12134
# Sentence: #Person1#: 최고라... 그렇군요? 그렇게 많은 회사들이 있는데, 어떻게 그들은 그런 탄탄한 위치를 확립했나요?
# ----------------------------------------
# File: train_12144
# Sentence: #Person1#: 좋아, 왜냐하면 나는 윌리엄에게 정말 화가 나거든. 내 말은, 나처럼 똑똑하고 아름다운 여성을 인정하지 못하는 바보 같은 사람이 누구야? 그 사람이랑 친구인 사람은 정말 멍청해.
# ----------------------------------------
# File: train_12147
# Sentence: #Person1#: 알겠어요, 엄마. 다음 번에는 시험에 떨어지지 않을게요.
# ----------------------------------------
# File: train_12150
# Sentence: #Person1#: 여기에 서서 당신을 묻는 것이 이상하게 느껴지네요, 하지만 이건 당신이 아니에요.
# ----------------------------------------
# File: train_12167
# Sentence: #Person1#: 하하하! 그래, 남자들만의 세상이지!
# ----------------------------------------
# File: train_12177
# Sentence: #Person1#: 그럼 말해봐요, 이사회, CEO, 그리고 주주들 사이에 무슨 차이가 있는 건가요? 저에게는 모두 같은 사람들로 보여요...
# ----------------------------------------
# File: train_12177
# Sentence: #Person2#: 아니요, 확실히 차이가 있어요. 주주들은 회사를 소유한 사람들이죠... 그들은 재무적인 통제 시스템인거죠. 그리고 CEO, 최고 경영 책임자가 있어요. 그는 핵심 인물로, 사장이에요. 만약 조직에 절대적인 권력을 가진 사람이 단 한 명만 있다면, 그 권력이 그들의 머리로 갈 것이라는 것을 모두 알고 있어요. 그건 너무 위험합니다. 그래서 이사회가 필요한 거예요. 이사회는 업계 전문가들로 구성돼요. 그들은 조직과 관련이 있을 수도 있지만, 대체로 독립적이고 편향적이지 않아요.
# ----------------------------------------
# File: train_12180
# Sentence: #Person1#: 어떤 수수료 조건을 제시하실 수 있나요?
# ----------------------------------------
# File: train_12180
# Sentence: #Person2#: 보통 수수료는 할인금액을 차감한 순송장 금액의 3%입니다.
# ----------------------------------------
# File: train_12180
# Sentence: #Person1#: 수수료를 5%로 올릴 수 없을까요?
# ----------------------------------------
# File: train_12185
# Sentence: #Person1#: 조금씩 줄여보는 것에 대해 생각해 본 적 있나요? 서서히 할 수 있을 거예요.
# ----------------------------------------
# File: train_12187
# Sentence: #Person1#: 이제 우리의 모든 물건들을 다시 찾을 수 없을 거라는 것이 확실해요. 이 범죄자들은 너무 똑똑하니까요. 다른 사람들이 훔쳐가도록 아름다운 물건들을 수집하는 것이 무슨 의미가 있을까요?
# ----------------------------------------
# File: train_12189
# Sentence: #Person2#: 네가 스스로 알아내야 해.
# ----------------------------------------
# File: train_12191
# Sentence: #Person1#: 좀 더 자세한 검사를 받는 게 좋을 것 같아요. 그리고 결과가 나오기 전에는 스스로를 편안하게 하고 잠자기 전에 약을 먹어보세요. 그러면 통증을 완화시키고 잠을 잘 수 있게 도와줄 거예요.
# ----------------------------------------
# File: train_12200
# Sentence: #Person1#: 이 냉장고에는 제빙기, 정수기, 그리고 내부에 넉넉한 공간이 있어요.
# ----------------------------------------
# File: train_12224
# Sentence: #Person1#: 하하, 두려워서 그런 것은 아니고 그저 접시를 다 비우는 것이 너무 눈에 띄어서 그런 것 같습니다.
# ----------------------------------------
# File: train_12226
# Sentence: #Person1#: 오늘 마치기 전에 이 회의의 고정 시간을 정하고 싶습니다. 모두들 일정을 확인해 주실 수 있나요?
# ----------------------------------------
# File: train_12230
# Sentence: #Person2#: 그건 다르지. 일할 때는 다른 마음 상태에 있어. 하지만 그녀에게 고백하려고 생각만 해도 말이 턱 막히더라고. 적어도 쪽지에서는 얼굴이 빨개지지 않고 말을 할 수 있어.
# ----------------------------------------
# File: train_12250
# Sentence: #Person1#: 하지만 아직 얼음이 충분히 단단하지 않은 것 같아요. 위험할 수 있어요.
# ----------------------------------------
# File: train_12252
# Sentence: #Person1#: 상상이 가네. 일은 어떤가?
# ----------------------------------------
# File: train_12259
# Sentence: #Person2#: 그래. 친구의 생일 파티였어. 우린 맥주, 와인, 술 등등 다양한 종류의 술을 마셨어. 자정이 넘어서는 칵테일까지 마셨어!
# ----------------------------------------
# File: train_12267
# Sentence: #Person2#: 네, 그것이 작업을 방해해요. 휴대폰을 끄면 집중하기가 더 쉬워져요. 나중에 메시지를 읽을 수 있어요.
# ----------------------------------------
# File: train_12269
# Sentence: #Person1#: 그럼요, 아마도. 티켓이 없다면 줄을 서서 기다려야 할 것 같아요.
# ----------------------------------------
# File: train_12270
# Sentence: #Person2#: 휴가, 개인 사유, 병가 등으로 사용할 수 있는 총 21일의 유급 휴가가 있습니다.
# ----------------------------------------
# File: train_12273
# Sentence: #Person1#: 아아니요, 컴퓨터에 바이러스가 있을 수도 있고, 나쁜 프로그램이 실행되어 있을 수도 있어요. 아마 그래서 컴퓨터가 다운되었을 수도 있어요. 원치 않는 스파이웨어나 트로이 목마를 안전하게 제거하기 위해서 바이러스 백신 프로그램을 실행하는 것을 추천합니다.
# ----------------------------------------
# File: train_12276
# Sentence: #Person1#: 베르사체, 캘빈 클라인, 비비안 웨스트우드 같은 최고의 패션 디자이너가 디자인한 이 옷들을 보세요. 여러분은 이 옷들을 어떻게 생각하나요?
# ----------------------------------------
# File: train_12280
# Sentence: #Person2#: 얼마나 자주 만나나요?
# ----------------------------------------
# File: train_12291
# Sentence: #Person1#: 물론이죠. 대부분의 얼굴 관리는 철저한 클렌징으로 시작됩니다. 그런 다음 일반적으로 토너를 사용하여 피부에 활력을 준 다음 피부를 칙칙하게 만드는 죽은 세포를 제거하는 필링 마스크 또는 스크럽과 같은 각질 제거 트리트먼트를 사용합니다. 그 후에는 오일이나 크림으로 얼굴과 목을 마사지하여 순환을 개선하고 긴장을 풀어주고, 마스크를 사용하여 피부를 촉촉하게 만들고 부드럽게 합니다.
# ----------------------------------------
# File: train_12294
# Sentence: #Person2#: 이런, 너 엄마 같아. 봐봐, 이건 정말 아름다워!
# ----------------------------------------
# File: train_12294
# Sentence: #Person2#: 오! 어, 봐봐, 그게 바로 브리트니가 콘서트에서 입었던 셔츠야.
# ----------------------------------------
# File: train_12296
# Sentence: #Person2#: 섬유는 전통적인 산업으로, 완전한 카탈로그와 탄탄한 기반을 가지고 있으며, 지난 몇 년 동안 발전해 왔습니다. 수출이 많으며, 수출 제품의 25% 이상을 차지하고 있습니다.
# ----------------------------------------
# File: train_12298
# Sentence: #Person2#: 하하하! 동감이에요. 그건 재미없죠.
# ----------------------------------------
# File: train_12301
# Sentence: #Person2#: 네, 휴가가 그리 멀지 않아요. 이 광고들을 보고 있었어요.
# ----------------------------------------
# File: train_12301
# Sentence: #Person1#: '3주.' '흥미진진한 10개의 항구.' '배를 호텔로 사용하세요.' 이건 얼마나 드나요?
# ----------------------------------------
# File: train_12309
# Sentence: #Person2#: 하하. 제 가족에서는 피임과 낙태는 금기어입니다.
# ----------------------------------------
# File: train_12322
# Sentence: #Person1#: 아하하, 그럼 네가 체중을 줄일 수 있겠네.
# ----------------------------------------
# File: train_12329
# Sentence: #Person2#: 예를 들어, 내가 건축을 공부하지 않았다면, 원하던 대로 예술가가 됐을 거야.
# ----------------------------------------
# File: train_12337
# Sentence: #Person1#: 와, 정말 흥미진진할 것 같아, 특히 유명한 선수들이 많이 참가하니까.
# ----------------------------------------
# File: train_12349
# Sentence: #Person2#: 당신이 정말로 아내를 사랑한다면, 그녀를 지지해야 합니다. 물론, 둘 다 할 수는 없겠죠.
# ----------------------------------------
# File: train_12350
# Sentence: #Person1#: 무엇이든 해주세요. 제 작은 프랭키가 괜찮아지길 바라는 거에요. 제 작은 햄스터 없는 삶을 상상조차 할 수 없어요!
# ----------------------------------------
# File: train_12351
# Sentence: #Person2#: 너의 생일을 축하하고, 앞으로의 행복, 건강, 그리고 지속적인 성공을 바랄꼐. 나는 페어리 플라워에서 너에게 꽃다발을 보내달라고 부탁했어. 너가 그것을 좋아하길 바래.
# ----------------------------------------
# File: train_12359
# Sentence: #Person2#: 음, 저는 환자에게 수면제를 주는 것을 별로 좋아하지 않아요. 꼭 충분히 휴식을 취하거나 일에 대해 잊어버려야 해요. 잠이 오지 않으면, 침대에 들어가기 전에 뜨거운 목욕을 하고 지루한 책을 읽어보세요. 흥미진진한 책은 사용하지 마시고, 커피도 마시지 마세요.
# ----------------------------------------
# File: train_12360
# Sentence: #Person1#: 수잔나, 이 사진 좀 봐봐. 절벽 근처인데, 어디에서 찍었는지 기억이 안 나.
# ----------------------------------------
# File: train_12388
# Sentence: #Person1#: 좋은 준비는 회의의 효과성을 향상시키죠. 당신의 열심히 일하는 모습이 결국에는 보상받을 거라고 확신해요.
# ----------------------------------------
# File: train_12393
# Sentence: #Person1#: 하지만 영화 보러 가는 것이 스스로를 더 잘 편안하게 할 수 있는 방법이라고 생각해.
# ----------------------------------------
# File: train_12409
# Sentence: #Person2#: 와, 멤버들은 어디에서 만나나요?
# ----------------------------------------
# File: train_12411
# Sentence: #Person1#: 저는 계산대 뒤에 서서 피자 주문을 받았어요.
# ----------------------------------------
# File: train_12447
# Sentence: #Person1#: 잘 준비하면 회의의 효과성이 향상될 것입니다. 당신의 열심히 일하는 모습이 결국에는 보상받을 거라고 확신합니다.
# ----------------------------------------

# %% [markdown]
# ## 연속된 세 글자(train)

# %%
import pandas as pd
import re

def find_repeated_hangul(file_path, excluded_words):
    df = pd.read_csv(file_path)
    
    if 'dialogue' not in df.columns:
        raise ValueError("'dialogue' 열이 CSV 파일에 없습니다.")
    
    # 한글 자음과 모음의 유니코드 범위 정의
    repeated_hangul_pattern = re.compile(r'([가-힣])\1{2,}')  # 동일 한글 글자가 3번 이상 연속하는 패턴
    
    results = []

    for _, row in df.iterrows():
        fname = row['fname']
        dialogue = row['dialogue']
        
        # 문장 단위로 분리
        sentences = dialogue.split('\n')  # 각 문장은 줄바꿈으로 구분된다고 가정

        for sentence in sentences:
            # 연속된 동일 한글 글자를 찾기 위한 정규 표현식
            repeated_hangul = re.findall(repeated_hangul_pattern, sentence)
            
            # 연속된 한글이 발견되었고, 제외할 단어가 포함되지 않은 경우
            if repeated_hangul and not any(excluded_word in sentence for excluded_word in excluded_words):
                results.append((fname, sentence))
    
    return results

if __name__ == "__main__":
    import platform
    
    os_name = platform.system()
    if os_name == 'Windows':
        PRE_PATH = ''
    elif os_name == 'Linux':
        PRE_PATH = '/kkh/'
    elif os_name == 'Darwin': # 맥
        PRE_PATH = '/kkh/'

    DATA_PATH = PRE_PATH + "data/"
    file_path = DATA_PATH + 'train.csv'  # 또는 'dev.csv'로 변경 가능
    
    excluded_words = ["몇몇", "멋지지", "각각"]
    
    # 연속된 동일 한글 찾기
    repeated_hangul_results = find_repeated_hangul(file_path, excluded_words)
    
    # 결과 출력
    if repeated_hangul_results:
        for fname, sentence in repeated_hangul_results:
            print(f"File: {fname}")
            print(f"Sentence: {sentence}")
            print("-" * 40)
    else:
        print("No repeated Hangul characters found.")
# Out:
# File: train_276
# Sentence: #Person1#: 헤이, 그게 뭐예요? [아아아!]
# ----------------------------------------
# File: train_460
# Sentence: #Person2#: 아아아아아아
# ----------------------------------------
# File: train_901
# Sentence: #Person1#: (고통 속에서 울며) 아아아!
# ----------------------------------------
# File: train_998
# Sentence: #Person2#: 하하하, 너 피곤하다고 했잖아.
# ----------------------------------------
# File: train_1732
# Sentence: #Person2#: 아아아아, 아아아아.
# ----------------------------------------
# File: train_1907
# Sentence: #Person1#: 아아아악!
# ----------------------------------------
# File: train_2464
# Sentence: #Person1#: 그냥 똑똑똑 떨어지는 정도입니다. 그것도 물이 아니죠.
# ----------------------------------------
# File: train_2727
# Sentence: #Person1#: 하하하, 아마 그게 너에게 체중 감량에 도움이 될지도 몰라.
# ----------------------------------------
# File: train_4271
# Sentence: #Person2#: 잭, 너의 유머 감각이 그립다. 하하하! 세상에 너처럼 사는 사람은 처음 봤다. 넌 정말 천부적이야.
# ----------------------------------------
# File: train_4401
# Sentence: #Person2#: 아아아아악! 침이 고이기 시작하던 참인데!
# ----------------------------------------
# File: train_5429
# Sentence: #Person2#: 고마워. 일단 안녕. 키스스스스스.
# ----------------------------------------
# File: train_6260
# Sentence: #Person1#: 그래. [주먹질과 발차기와 고함과 비명을 지르는 소리 ... ] 아, 오, 맨. 아아아. 아파.
# ----------------------------------------
# File: train_6563
# Sentence: #Person2#: 허허허 ... 여자들이란!
# ----------------------------------------
# File: train_7662
# Sentence: #Person2#: 하하하. 미안해. 그냥 장난이었어.
# ----------------------------------------
# File: train_8060
# Sentence: #Person2#: 하하하, 너 피곤하다고 했잖아.
# ----------------------------------------
# File: train_8206
# Sentence: #Person1#: 하하하.
# ----------------------------------------
# File: train_9608
# Sentence: #Person1#: 이런 것들은 항상 너어어어무 지루해. 아무 소문 들은거 없어? 누구 큰 돈 번 사람 없나?
# ----------------------------------------
# File: train_9982
# Sentence: #Person1#: 하하하! 그렇군요, 그건 제가 받아들여야겠네요. 설명해 드릴게요, 괜찮겠습니까?
# ----------------------------------------
# File: train_10295
# Sentence: #Person1#: 하하하, 어디선가 아이스 커피라도 얻을 수 있으면 좋겠다.
# ----------------------------------------
# File: train_11053
# Sentence: #Person2#: 아, 그건 쉬워요. 그는 밝은 빨간색 부츠와 보라색 모자를 썼어요... 음, 당신이 쓴 것처럼. 헤헤헤...
# ----------------------------------------
# File: train_11677
# Sentence: #Person1#: 으으으으!!!
# ----------------------------------------
# File: train_12167
# Sentence: #Person1#: 하하하! 그래, 남자들만의 세상이지!
# ----------------------------------------
# File: train_12298
# Sentence: #Person2#: 하하하! 동감이에요. 그건 재미없죠.
# ----------------------------------------

# %% [markdown]
# ## 연속된 세 글자(dev)

# %%
import pandas as pd
import re

def find_repeated_hangul(file_path, excluded_words):
    df = pd.read_csv(file_path)
    
    if 'dialogue' not in df.columns:
        raise ValueError("'dialogue' 열이 CSV 파일에 없습니다.")
    
    # 한글 자음과 모음의 유니코드 범위 정의
    repeated_hangul_pattern = re.compile(r'([가-힣])\1{2,}')  # 동일 한글 글자가 3번 이상 연속하는 패턴
    
    results = []

    for _, row in df.iterrows():
        fname = row['fname']
        dialogue = row['dialogue']
        
        # 문장 단위로 분리
        sentences = dialogue.split('\n')  # 각 문장은 줄바꿈으로 구분된다고 가정

        for sentence in sentences:
            # 연속된 동일 한글 글자를 찾기 위한 정규 표현식
            repeated_hangul = re.findall(repeated_hangul_pattern, sentence)
            
            # 연속된 한글이 발견되었고, 제외할 단어가 포함되지 않은 경우
            if repeated_hangul and not any(excluded_word in sentence for excluded_word in excluded_words):
                results.append((fname, sentence))
    
    return results

if __name__ == "__main__":
    import platform
    
    os_name = platform.system()
    if os_name == 'Windows':
        PRE_PATH = ''
    elif os_name == 'Linux':
        PRE_PATH = '/kkh/'
    elif os_name == 'Darwin': # 맥
        PRE_PATH = '/kkh/'

    DATA_PATH = PRE_PATH + "data/"
    file_path = DATA_PATH + 'dev.csv'  # 또는 'dev.csv'로 변경 가능
    
    excluded_words = ["몇몇", "멋지지", "각각"]
    
    # 연속된 동일 한글 찾기
    repeated_hangul_results = find_repeated_hangul(file_path, excluded_words)
    
    # 결과 출력
    if repeated_hangul_results:
        for fname, sentence in repeated_hangul_results:
            print(f"File: {fname}")
            print(f"Sentence: {sentence}")
            print("-" * 40)
    else:
        print("No repeated Hangul characters found.")
# Out:
# File: dev_334
# Sentence: #Person1#: 아아아. 아직. 내가 식습관을 바꾸려고 결정했어.
# ----------------------------------------
# File: dev_405
# Sentence: #Person2#: 제제제... 여자들이란!
# ----------------------------------------
