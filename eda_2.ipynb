# %%
import pandas as pd

translated = pd.read_csv('./dj/translated.csv')
train = pd.read_csv('./dj/data/train.csv')

# %%
translated.head(5)
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0    fname  \
# 0             0             0           0  train_0
# 1             1             1           1  train_1
# 2             2             2           2  train_2
# 3             3             3           3  train_3
# 4             4             4           4  train_4
#
#                                             dialogue  \
# 0  #Person1#: 안녕하세요, 스미스씨. 저는 호킨스 의사입니다. 오늘 왜 오셨나...
# 1  #Person1#: 안녕하세요, Parker 부인, 어떻게 지내세요?\n#Perso...
# 2  #Person1#: 실례합니다, 열쇠 한 묶음 보셨나요?\n#Person2#: 어떤...
# 3  #Person1#: 왜 너는 여자친구가 있다는 걸 말해주지 않았어?\n#Person...
# 4  #Person1#: 안녕, 숙녀분들! 오늘 밤 당신들은 정말 멋져 보여. 이 춤을 ...
#
#                                              summary     topic  \
# 0  스미스씨가 건강검진을 받고 있고, 호킨스 의사는 매년 건강검진을 받는 것을 권장합니...   건강검진 받기
# 1  Parker 부인은 Ricky를 백신을 데려갔습니다.Peters는 기록을 확인하고 ...        백신
# 2  #Person1#은 열쇠 한 묶음을 찾고 있고, 그것을 찾기 위해 #Person2#...     열쇠 찾기
# 3  #Person1#은 #Person2#가 여자친구가 있고 그녀와 결혼할 것이라는 사실...  여자친구가 있다
# 4  말릭이 니키에게 춤을 요청한다. 말릭이 발을 밟는 것을 신경 쓰지 않는다면 니키는 ...        댄스
#
#                                        combined_text  similarity  \
# 0  건강검진 받기 #Person1#: 안녕하세요, 스미스씨. 저는 호킨스 의사입니다. ...    0.590560
# 1  백신 #Person1#: 안녕하세요, 파커 부인, 어떻게 지내셨나요?\n#Perso...    0.645074
# 2  열쇠 찾기 #Person1#: 실례합니다, 열쇠 한 묶음 보셨나요?\n#Person...    0.669059
# 3  여자친구가 있다 #Person1#: 왜 너는 여자친구가 있다는 걸 말해주지 않았어?...    0.756981
# 4  댄스 #Person1#: 안녕, 숙녀분들! 오늘 밤 당신들은 정말 멋져 보여. 이 ...    0.399786
#
#     topic_nouns  topic_percent  topic_similarity  combined_similarity  \
# 0  ['건강', '검진']            1.0          0.438091             1.028651
# 1        ['백신']            1.0          0.322626             0.967700
# 2        ['열쇠']            1.0          0.629212             1.298272
# 3  ['여자', '친구']            1.0          0.489802             1.246783
# 4        ['댄스']            0.0          0.316758             0.716544
#
#    k_percent  k_percent_dialogue  topic_dialogue_similarity english_words  \
# 0   1.000000            0.896552                   0.322930            []
# 1   1.000000            0.906250                   0.314679    ['B', 'A']
# 2   0.846154            0.836066                   0.403980            []
# 3   0.785714            0.857143                   0.275326            []
# 4   1.000000            0.898551                   0.251543            []
#
#    english_words_count
# 0                    0
# 1                    2
# 2                    0
# 3                    0
# 4                    0

# %%
translated.columns
# Out:
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'fname', 'dialogue',
#        'summary', 'topic', 'combined_text', 'similarity', 'topic_nouns',
#        'topic_percent', 'topic_similarity', 'combined_similarity', 'k_percent',
#        'k_percent_dialogue', 'topic_dialogue_similarity', 'english_words',
#        'english_words_count'],
#       dtype='object')

# %%
translated[['english_words',
       'english_words_count']]
# Out:
#       english_words  english_words_count
# 0                []                    0
# 1        ['B', 'A']                    2
# 2                []                    0
# 3                []                    0
# 4                []                    0
# ...             ...                  ...
# 12452            []                    0
# 12453            []                    0
# 12454            []                    0
# 12455            []                    0
# 12456            []                    0
#
# [12457 rows x 2 columns]

# %%
train[['english_words', 'english_words_count']] = translated[['english_words', 'english_words_count']]

# %%
con_eng = train[train['english_words_count'] > 0]

# %%
con_eng
# Out:
#              fname                                           dialogue  \
# 1          train_1  #Person1#: 안녕하세요, 파커 부인, 어떻게 지내셨나요?\n#Person2#...
# 8          train_8  #Person1#: 이것은 좋은 기본 컴퓨터 패키지입니다. 좋은 CPU, 256메가...
# 14        train_14  #Person1#: 어떤 종류의 음악을 듣는 것을 좋아하시나요?\n#Person2#...
# 24        train_24  #Person1#: 당신이 본 모든 영화 중에서 가장 좋아하는 것은 무엇인가요?\n...
# 35        train_35  #Person1#: 나는 텔레비전 보는 것이 지겨워. 오늘 밤에 영화관에 가자.\n...
# ...            ...                                                ...
# 12434  train_12437  #Person1#: 우리의 연결 항공편은 몇 시에 있나요?\n#Person2#: 확...
# 12437  train_12440  #Person1#: 은행에 어떻게 가는지 알려주실 수 있나요?\n#Person2#:...
# 12440  train_12443  #Person1#: 아빠, 나 샤론이랑 영화 보러 가도 돼?\n#Person2#: ...
# 12443  train_12446  #Person1#: 여기 있네요, 여러분, 먼저 버그너에 들려볼게요. 오늘 운이 좋...
# 12445  train_12448  #Person1#: 그래서 우리는 내년에 미국에서 판매를 시작하는 것 같아요. \n...
#
#                                                  summary    topic  \
# 1      파커 부인이 리키를 데리고 백신 접종을 하러 갔다. 피터스 박사는 기록을 확인한 후...       백신
# 8      #Person1#은 기본 컴퓨터 패키지를 #Person2#에게 보여줍니다. #Per...  컴퓨터 패키지
# 14     #Person2#는 댄스 음악을 좋아하고, #Person1#은 클래식 음악을 선호합...       음악
# 24     #Person1#과 #Person2# 모두 슈퍼 배드가 웃기다고 생각합니다. 그들은...       영화
# 35     #Person1#은 텔레비전 보는 것이 지겨워서, #Person1#과 #Person...    영화 보기
# ...                                                  ...      ...
# 12434  #Person1#과 #Person2#는 항공편과 게이트 번호에 대해 이야기합니다. ...   연결 항공편
# 12437  #Person1#은 #Person2#에게 Allied Irish Bank로 가는 길...     길 묻기
# 12440  #Person1#은 샤론과 영화를 보러 가고 싶어한다. #Person2#는 #Per...       성적
# 12443  #Person1#은 먼저 Bergner's의 할인 드레스를 보고 #Person2#와...   백화점 쇼핑
# 12445  존은 #Person2#에게 새로운 무역 협상 때문에 미국 사무소로 전근될 수도 있다...   미국 사무소
#
#                                            english_words  english_words_count
# 1                                             ['B', 'A']                    2
# 8                                  ['RAM', 'CPU', 'DVD']                    3
# 14                                                ['CD']                    1
# 24                                               ['DVD']                    1
# 35                                                ['TV']                    1
# ...                                                  ...                  ...
# 12434                                             ['OK']                    1
# 12437  ['Irish', 'Dunned', 'of', 'Allied', 'm', 'Stor...                    9
# 12440                                              ['C']                    1
# 12443  ['Calvin', 'Will', 's', 'Penny', 'l', 'Lerner'...                   10
# 12445                                         ['L', 'A']                    2
#
# [1690 rows x 6 columns]

# %%
i = 1400

# %%
i
# Out:
# 1586

# %%
row = con_eng.iloc[1584]

print(row['fname'])
print('-' * 100)
print(row['summary'])
print('-' * 100)
print(row['dialogue'])
print('-' * 100)
print(row['english_words'])
# Out:
# train_11710
# ----------------------------------------------------------------------------------------------------
# #Person2#는 자주 부모님과 배드민턴을 친다. 다니엘은 그것이 믿기지 않아하고 그는 축구를 좋아한다.
# ----------------------------------------------------------------------------------------------------
# #Person1#: 자주 운동하시나요?
# #Person2#: 물론이죠.
# #Person1#: 좋아요, 그럼 보통 어떤 종류의 스포츠를 주로 하시나요?
# #Person2#: 저는 부모님과 함께 배드민턴을 자주 쳐요.
# #Person1#: 당신이 배드민턴을 친다고요? 그게 믿기지 않아요! 당신은 라켓보다 작잖아요.
# #Person2#: 에이, 저는 그걸 잘 치는 거예요.
# #Person1#: 누가 그랬어요?
# #Person2#: 제 부모님이요.
# #Person1#: 아, 알겠어요.
# #Person2#: 당신은 어떤가요, 다니엘l?
# #Person1#: 나는 진짜 남자고, 나는 축구를 좋아해.
# #Person2#: 그럼, 당신이 가장 좋아하는 축구 선수는 누구인가요?
# #Person1#: 전는 레날도를 가장 좋아해요.
# ----------------------------------------------------------------------------------------------------
# ['l']

# %%
row = con_eng.iloc[i]

print(row['fname'])
print('-' * 100)
print(row['summary'])
print('-' * 100)
print(row['dialogue'])
print('-' * 100)
print(row['english_words'])

i += 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1805], line 1
# ----> 1 row = con_eng.iloc[i]
#       3 print(row['fname'])
#       4 print('-' * 100)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1714, in _iLocIndexer._getitem_axis(self, key, axis)
#    1711     raise TypeError("Cannot index by location index with a non-integer key")
#    1713 # validate the location
# -> 1714 self._validate_integer(key, axis)
#    1716 return self.obj._ixs(key, axis=axis)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexing.py:1647, in _iLocIndexer._validate_integer(self, key, axis)
#    1645 len_axis = len(self.obj._get_axis(axis))
#    1646 if key >= len_axis or key < -len_axis:
# -> 1647     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %% [markdown]
# 이상한 단어: '라페1', Ccd
# Ccd = cd인거 같다
# ICCC = IC가 아닐까?
# R$D = R&D가 아닐까?
#
# Baklava = 바크라바 O 바클라바 x
#
# Liu Yan = 리우 얀
#
# Wei = 사람이람...
#
# CAD = 케드
#
# uh는 지워도 되지 않을까
#
# FooWa 장식? flower 장식이 아닐까? 꽃
#
# train
#
# Economist = 이코노미스트
#
# summary에선 Quanjude
# dialoge에선 콴주드
#
# summary의 형태가 이러하네.. #Person1#이 쇼핑을 가자고 메리에게 제안합니다. 메리는 '싱크(sink)'라고 말합니다. #Person1#은 메리에게 발음 연습을 제안합니다.
#
# Asks의 EEE 노트북이네
#
# #Person2#: 외국의 관습과 비즈니스 관행의 뉘앙스와 차이를 이해하는 것의 중요성은 글로벌 기업가와 거래자에게 지속적인 도전입니다. 많은 국가들이 TO 회원국이 되었음에도 불구하고, 무역과 투자의 마찰은 여전히 기존 회원국들 사이에서 주요한 문제입니다. 그러나 이러한 마찰은 TO의 무역 규칙과 분쟁 해결 메커니즘 하에서 더 잘 관리될 것입니다.
#
# TO는 뭘까//
#
# II = 2  대부와 대부 II가 그렇습니다. 둘 다 프란시스 포드 코폴라가 감독했어요.
#
# rj = 거
#
# #person1 = #person1#
# person#
# Wudaokou = 우다오커우
#
# #Person2#: 미쳤어? 너 정말 무슨 말 하는지 모르는 것 같아! 눈을 위해서만 아이라이너, 속눈썹 컬러, 아이섀도, 눈썹 연필, 마스카라를 사야 해. 그리고 파운데이션, liq
# liq 뭘까?
#
# #Person1#: 나는 릴렉서를 받고, 끝을 Halle처럼 올려서 하려고 해.
# #Person2#: 저도 릴렉서를 받을 수 있을까요? 그리고 왜 '너 미쳤어'라고 말하는 대신 '너 정말 미쳤어'라고 말하지 않았어요?
# Halle?
#
#  discomgoogolation 철자 틀림['discombobulate', 'google', 'discomgoogolation', 'discomgooglation']
#
#  당신은 어떤가요, 다니엘l?
#  다니엘l? = 다니엘?
#
# 미 프로모션이 있었던 것 같던데. 그리고 s
# s 지우자.
#
# #Person1#: 정말 고마워요,윌l

# %% [markdown]
# 영어 나오는 경우
# 1. A형 B형 간염
# 2. CPU, DVD
# 3. CD, TV
# 4. 줄인말 A, B, C, D
# 5. 등급
# 6. 모델번호
# 7. 상표 B&
# 8. 이름
# 9. 이름 철자
# 10. 프로그래밍 언어
# 11. IT
# 12. 단위 cm
# 13. 지역 D.C = District of Columbia
# 14. KTCTWY = 메세지 전달...
# 15. 도로 이름 B
# 16. Ms 호칭
# 17. www 주소 'StudioClassroom
# 18. 학교이름 PCC
# 19. 은행이름
#
# 문제가 있는경우
# 1. #Person2#: 미안해요 톰, 우리가 당신의 말을 듣는데 문제가 있어요. 소리가 좀 퍼져요. 우리를 들을 수 있나요?
# #Person1#: ( XXXXXXXXXX ) // 잘못 들음

# %%
check = []

# %%
check.append(row['fname'])

# %%
check
# Out:
# ['train_72', 'train_5429']
